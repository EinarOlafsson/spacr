# %% [markdown]
# # Compare sequencing reads with phenotype scores
#
# **Purpose.** Join per-well guide abundance with imaging-derived phenotype scores and quantify their association.
#
# **Recommended use.** Use as a plate-registration and data-consistency check before regression analysis.
#
# **Primary outputs.** Joined per-well data and correlation figures.
#
# ---
#
# > Paths in this notebook are placeholders. Set `src` and any other required path to the experimental data before execution.
# > spaCR writes outputs within, or immediately adjacent to, the configured source directory unless an explicit output path is set.

# %% [markdown]
# ## 1. Verify the environment
#
# The following cell reports the installed spaCR version. Import errors must be resolved before the analysis cells are executed. GPU acceleration is optional and depends on the selected workflow and installed computational backend.

# %%
import spacr
from spacr.version import version_str

print(version_str)

# %% [markdown]
# ## 2. API entry point
#
# This workflow calls the following public function:
#
# - [`spacr.submodules.compare_reads_to_scores`](https://einarolafsson.github.io/spacr/api/spacr/submodules/index.html#spacr.submodules.compare_reads_to_scores)
#
# ```python
# compare_reads_to_scores(**settings)
# ```
#
# Parameter definitions and defaults are generated from the same public API and are listed in the settings reference below.

# %%
from spacr.submodules import compare_reads_to_scores

# %% [markdown]
# ## 3. Settings and API reference
#
# Review the parameter definitions here, then edit the values in the categorized code cells below. Required settings must be supplied. Optional settings retain the displayed default when unchanged. Conditionally required settings are necessary only for the indicated analysis branch. Defaults and descriptions are generated from the installed spaCR version so that the notebook remains aligned with the public API.
#
# ### [`spacr.submodules.compare_reads_to_scores`](https://einarolafsson.github.io/spacr/api/spacr/submodules/index.html#spacr.submodules.compare_reads_to_scores)
#
#
# #### Plate Layout & Controls
#
# - **`plate`** *(optional)* — plate ID to stamp when a single pair of CSVs is given.
#
# #### Additional settings
#
# - **`column`** *(optional)* — column used to select a subset of wells. Default ``'columnID'``.
# - **`empirical_dict`** *(optional)* — mapping of ``rowID`` to ``(pc_units, nc_units)`` mixture; a 16-row default is used when ``None``.
# - **`nc_grna`** *(optional)* — negative-control gRNA name. Default ``'TGGT1_233460_4'``.
# - **`pc_grna`** *(optional)* — positive-control gRNA name. Default ``'TGGT1_220950_1'``.
# - **`reads_csv`** *(required)* — path (or list of paths) to per-gRNA read count CSVs.
# - **`save_paths`** *(optional)* — two-element list of PDF output paths (pc plot, nc plot).
# - **`scores_csv`** *(required)* — path (or list of paths) to per-object classifier score CSVs.
# - **`value`** *(optional)* — value in ``column`` to keep. Default ``'c3'``.
# - **`y_columns`** *(optional)* — columns to plot on the y axis; a sensible default is used when ``None``.
#
# ## 4. Run
#
# After editing the settings cell, run the function cell immediately below it. Long operations report progress through spaCR's logging system; set `SPACR_LOG_LEVEL=DEBUG` before starting Jupyter for more detail.

# %%
settings = {
    # Plate Layout & Controls
    # Optional settings
    'plate': None,

    # Additional settings
    # Required settings
    'reads_csv': None,
    'scores_csv': None,
    # Optional settings
    'column': 'columnID',
    'empirical_dict': None,
    'nc_grna': 'TGGT1_233460_4',
    'pc_grna': 'TGGT1_220950_1',
    'save_paths': None,
    'value': 'c3',
    'y_columns': None,
}

# %%
compare_reads_to_scores(**settings)

# %% [markdown]
# ## Outputs and next steps
#
# Joined per-well data and correlation figures.
#
# Output directories remain associated with the source dataset, which preserves plate-level provenance across subsequent spaCR workflows.
#
# ### Related documentation
#
# - [Graphical workflow tutorials](https://einarolafsson.github.io/spacr/tutorials/)
# - [Python API reference](https://einarolafsson.github.io/spacr/python_api.html)
