# %% [markdown]
# # Analyze activation maps
#
# **What it does.** Summarise a folder of activation maps into per-class statistics.
#
# **When to use it.** After generating activation maps, to compare what the model attends to between classes.
#
# **What you get.** Per-class attention summaries and comparison figures.
#
# ---
#
# > Every path below is a placeholder. Point `src` at your own data before running.
# > Nothing in this notebook writes outside the folder you give it.

# %% [markdown]
# ## 1. Check the install
#
# If this cell fails, the rest cannot work. It reports the version and whether a GPU is visible — segmentation and training are usable on CPU but slow.

# %%
import spacr
from spacr.version import version_str

print(version_str)

# %% [markdown]
# ## 2. The function this notebook runs
#
# `spacr.deep_spacr.analyze_activation_maps`
#
# ```
# analyze_activation_maps(model, images, methods=None, *, masks=None, target=None, target_layer=None, model_type=None, n_steps=12, baseline='blur', sanity_check=True, sanity_threshold=0.5, verbose=True)
# ```
#
# Attribute images several ways and report whether any of it is trustworthy.

# %%
from spacr.deep_spacr import analyze_activation_maps

# %% [markdown]
# ## 3. Call it
#
# This entry point takes plain arguments rather than a settings dictionary. The signature above is authoritative; fill in the arguments it names.
#
# The cell is left deliberately incomplete so it cannot run against the wrong data by accident.

# %% [markdown]
# ### Every setting this function accepts
#
# Every key, with its default and what it controls. Edit values in place; delete nothing — a key left at its default behaves exactly as if it were absent.
#
# Generated from this installed version by `tools/build_notebook_settings.py`, so these are the real keys, the real defaults and the real descriptions. Re-run that tool after upgrading spaCR.

# %%
# Generated by tools/build_notebook_settings.py — do not edit by hand.
# Values are this installed version's defaults; the text above each key is
# its live description. Edit values in place -- a key left at its default
# behaves exactly as if it were absent.

# spacr.deep_spacr.analyze_activation_maps  (12 settings)
settings = {
    # what removed pixels become — ``'blur'``, ``'zero'``, ``'mean'`` or
    # ``'uniform'``.
    'baseline': 'blur',

    # one image tensor, or a sequence of them, ``(C, H, W)``.
    'images': None,

    # optional per-image boolean object masks for the pointing game.
    'masks': None,

    # method names from :data:`spacr.attribution.ATTRIBUTION_METHODS`;
    # defaults to one representative of each family.
    'methods': None,

    # the trained classifier.
    'model': None,

    # architecture name, used to make errors readable.
    'model_type': None,

    # steps in the deletion / insertion curves.
    'n_steps': 12,

    # run the randomisation check (on the first image).
    'sanity_check': True,

    # rank correlation below which a method passes.
    'sanity_threshold': 0.5,

    # class index to explain; defaults to each image's prediction.
    'target': None,

    # CAM target layer, or None for the last convolution.
    'target_layer': None,

    # print the per-method verdicts.
    'verbose': True,
}

# %%
analyze_activation_maps(**settings)

# %% [markdown]
# ## Where the output went
#
# Per-class attention summaries and comparison figures.
#
# spaCR writes beside the source folder rather than into a global location, so a plate stays self-contained and re-running does not clobber a different experiment.
#
# ### Next steps
#
# * The GUI covers the same workflows with the settings laid out as a form — `python -m spacr`.
# * The narrated walkthroughs are at <https://einarolafsson.github.io/spacr/tutorials/>.
# * The API reference is at <https://einarolafsson.github.io/spacr/>.
