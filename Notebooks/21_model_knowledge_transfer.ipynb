# %% [markdown]
# # Transfer knowledge between models
#
# **Purpose.** Train a student image classifier using predictions from one or more teacher models.
#
# **Recommended use.** Use when adapting validated predictive information to a related dataset or consolidating teacher models into a student architecture.
#
# **Primary outputs.** A trained student model and recorded training provenance.
#
# ---
#
# > Paths in this notebook are placeholders. Set `src` and any other required path to the experimental data before execution.
# > spaCR writes outputs within, or immediately adjacent to, the configured source directory unless an explicit output path is set.

# %% [markdown]
# ## 1. Verify the environment
#
# The following cell reports the installed spaCR version. Import errors must be resolved before the analysis cells are executed. GPU acceleration is optional and depends on the selected workflow and installed computational backend.

# %%
import spacr
from spacr.version import version_str

print(version_str)

# %% [markdown]
# ## 2. API entry point
#
# This workflow calls the following public function:
#
# - [`spacr.deep_spacr.model_knowledge_transfer`](https://einarolafsson.github.io/spacr/api/spacr/deep_spacr/index.html#spacr.deep_spacr.model_knowledge_transfer)
#
# ```python
# model_knowledge_transfer(**settings)
# ```
#
# Parameter definitions and defaults are generated from the same public API and are listed in the settings reference below.

# %%
from spacr.deep_spacr import model_knowledge_transfer

# %% [markdown]
# ## 3. Settings and API reference
#
# Review the parameter definitions here, then edit the values in the categorized code cells below. Required settings must be supplied. Optional settings retain the displayed default when unchanged. Conditionally required settings are necessary only for the indicated analysis branch. Defaults and descriptions are generated from the installed spaCR version so that the notebook remains aligned with the public API.
#
# ### [`spacr.deep_spacr.model_knowledge_transfer`](https://einarolafsson.github.io/spacr/api/spacr/deep_spacr/index.html#spacr.deep_spacr.model_knowledge_transfer)
#
#
# #### Computer Vision Training
#
# - **`epochs`** *(optional)* — Training epochs. Default ``10``.
#
# #### Computer Vision Optimization and Regularization
#
# - **`use_checkpoint`** *(optional)* — Whether to enable gradient checkpointing.
# - **`dropout_rate`** *(optional)* — Optional dropout rate for the student.
#
# #### Regression: Model Tuning
#
# - **`alpha`** *(optional)* — Weight on the true-label loss vs. distillation loss. Default ``0.5``.
#
# #### Additional settings
#
# - **`data_loader`** *(required)* — Training DataLoader used during distillation.
# - **`device`** *(optional)* — Torch device string. Default ``'cpu'``.
# - **`lr`** *(optional)* — Adam learning rate. Default ``1e-4``.
# - **`pretrained`** *(optional)* — Whether the student uses pretrained weights.
# - **`student_model_name`** *(optional)* — TorchModel architecture name for the student. Default ``'maxvit_t'``.
# - **`student_save_path`** *(required)* — Destination for the trained student; the suffix ``_KD.pth`` is appended.
# - **`teacher_paths`** *(required)* — Paths to the teacher checkpoints (each either a saved ``TorchModel`` or a state dict).
# - **`temperature`** *(optional)* — Softmax temperature for distillation. Default ``2.0``.
#
# ## 4. Run
#
# After editing the settings cell, run the function cell immediately below it. Long operations report progress through spaCR's logging system; set `SPACR_LOG_LEVEL=DEBUG` before starting Jupyter for more detail.

# %%
settings = {
    # Computer Vision Training
    # Optional settings
    'epochs': 10,

    # Computer Vision Optimization and Regularization
    # Optional settings
    'use_checkpoint': False,
    'dropout_rate': None,

    # Regression: Model Tuning
    # Optional settings
    'alpha': 0.5,

    # Additional settings
    # Required settings
    'data_loader': None,
    'student_save_path': None,
    'teacher_paths': None,
    # Optional settings
    'device': 'cpu',
    'lr': 0.0001,
    'pretrained': True,
    'student_model_name': 'maxvit_t',
    'temperature': 2.0,
}

# %%
model_knowledge_transfer(**settings)

# %% [markdown]
# ## Outputs and next steps
#
# A trained student model and recorded training provenance.
#
# Output directories remain associated with the source dataset, which preserves plate-level provenance across subsequent spaCR workflows.
#
# ### Related documentation
#
# - [Graphical workflow tutorials](https://einarolafsson.github.io/spacr/tutorials/)
# - [Python API reference](https://einarolafsson.github.io/spacr/python_api.html)
