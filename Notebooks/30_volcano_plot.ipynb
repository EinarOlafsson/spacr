# %% [markdown]
# # Volcano plot
#
# **What it does.** Draw effect size against significance, with the hits labelled.
#
# **When to use it.** The standard summary figure for a screen.
#
# **What you get.** A publication-shaped volcano plot.
#
# ---
#
# > Every path below is a placeholder. Point `src` at your own data before running.
# > Nothing in this notebook writes outside the folder you give it.

# %% [markdown]
# ## 1. Check the install
#
# If this cell fails, the rest cannot work. It reports the version and whether a GPU is visible — segmentation and training are usable on CPU but slow.

# %%
import spacr
from spacr.version import version_str

print(version_str)

# %% [markdown]
# ## 2. The function this notebook runs
#
# `spacr.toxo.custom_volcano_plot`
#
# ```
# custom_volcano_plot(data_path, metadata_path, metadata_column='tagm_location', point_size=50, figsize=20, threshold=0, save_path=None, x_lim=None, y_lims=None)
# ```
#
# Render a volcano plot coloured by T. gondii subcellular localisation.

# %%
from spacr.toxo import custom_volcano_plot

# %% [markdown]
# ## 3. Call it
#
# This entry point takes plain arguments rather than a settings dictionary. The signature above is authoritative; fill in the arguments it names.
#
# The cell is left deliberately incomplete so it cannot run against the wrong data by accident.

# %% [markdown]
# ### Every setting this function accepts
#
# Every key, with its default and what it controls. Edit values in place; delete nothing — a key left at its default behaves exactly as if it were absent.
#
# Generated from this installed version by `tools/build_notebook_settings.py`, so these are the real keys, the real defaults and the real descriptions. Re-run that tool after upgrading spaCR.

# %%
# Generated by tools/build_notebook_settings.py — do not edit by hand.
# Values are this installed version's defaults; the text above each key is
# its live description. Edit values in place -- a key left at its default
# behaves exactly as if it were absent.

# spacr.toxo.custom_volcano_plot  (11 settings)
settings = {
    # Regression table containing ``feature``, ``coefficient``, and
    # ``p_value`` columns. DataFrame input is copied.
    'data_path': None,

    # Build, optionally save, and show the figure. If false, return the
    # hit list before constructing a figure.
    'draw': True,

    # Width and height of the square figure in inches. Typography scales
    # with this value.
    'figsize': 20,

    # Values from ``metadata_column`` to overlay in the highlight colour
    # and name in the in-panel legend.
    'highlight_location': None,

    # Localization or annotation column used by ``highlight_location``.
    'metadata_column': 'tagm_location',

    # Gene metadata containing one row per ``gene_nr`` and the selected
    # metadata column. DataFrame input is copied.
    'metadata_path': None,

    # Marker area passed to ``Axes.scatter``.
    'point_size': 50,

    # Destination passed to :func:`spacr.plot.save_figure`. The written
    # extension follows the configured figure format.
    'save_path': None,

    # Absolute coefficient threshold for calls. A row is returned when
    # ``p_value <= 0.05`` and ``abs(coefficient) >= abs(threshold)``.
    'threshold': 0,

    # Two x-axis limits. The default is ``[-0.5, 0.5]``.
    'x_lim': None,

    # Use ``[low, high]`` for one axis or ``[[lower_low, lower_high],
    # [upper_low, upper_high]]`` for a broken y-axis. By default, fit one
    # axis to the finite values.
    'y_lims': None,
}

# %%
custom_volcano_plot(**settings)

# %% [markdown]
# ## Where the output went
#
# A publication-shaped volcano plot.
#
# spaCR writes beside the source folder rather than into a global location, so a plate stays self-contained and re-running does not clobber a different experiment.
#
# ### Next steps
#
# * The GUI covers the same workflows with the settings laid out as a form — `python -m spacr`.
# * The narrated walkthroughs are at <https://einarolafsson.github.io/spacr/tutorials/>.
# * The API reference is at <https://einarolafsson.github.io/spacr/>.
