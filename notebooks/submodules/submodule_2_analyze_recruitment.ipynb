# %%
# Calculate recruitment.
from spacr.submodules import analyze_recruitment
# %matplotlib inline

settings = {'target':'protein',
            'cell_types':['wt', 'alg2'],
            'cell_plate_metadata':[['c1','c2','c3','c4','c5','c6','c7','c8','c9','c10','c11','c12'],['c13','c14','c15','c16','c17','c18','c19','c20','c21','c22','c23','c24']],
            'pathogen_types':['wt', 'd98', 'comp'],
            'pathogen_plate_metadata':[['c1','c2','c3','c4','c13','c14','c15','c16'],['c5','c6','c7','c8','c17','c18','c19','c20'],['c9','c10','c11','c12','c21','c22','c23','c24']],
            'treatments':['one', 'two', 'three'],
            'treatment_plate_metadata':[['c1','c5','c9','c13','c17','c21'],['c2','c6','c10','c11','c14','c18','c22'],['c3','c4','c7','c8','c12','c15','c16','c19','c20','c23','c24']],
            'channel_dims':[0,1,2,3],
            'cell_chann_dim':3,
            'cell_mask_dim':4,
            'nucleus_chann_dim':0,
            'nucleus_mask_dim':5,
            'pathogen_chann_dim':2,
            'pathogen_mask_dim':6,
            'channel_of_interest':2,
            'plot':True,
            'plot_nr':1,
            'plot_control':True,
            'figuresize':20,
            'remove_background':True,
            'backgrounds':100,
            'pathogen_limit':3,
            'nuclei_limit':1,
            'cells_per_well':100,
            'pathogen_size_range':[0,100000],
            'nucleus_size_range':[0,100000],
            'cell_size_range':[0,100000],
            'pathogen_intensity_range':[0,100000],
            'nucleus_intensity_range':[0,100000],
            'cell_intensity_range':[0,100000],
            'target_intensity_min':0}

settings['src'] = '/nas_mnt/carruthers/anu/anuALG2_20241222_104105/plate1'

dfs = analyze_recruitment(settings)
# Out:
# Cell(s): ['wt', 'alg2'], in [['c1', 'c2', 'c3', 'c4', 'c5', 'c6', 'c7', 'c8', 'c9', 'c10', 'c11', 'c12'], ['c13', 'c14', 'c15', 'c16', 'c17', 'c18', 'c19', 'c20', 'c21', 'c22', 'c23', 'c24']]
# Pathogen(s): ['wt', 'd98', 'comp'], in [['c1', 'c2', 'c3', 'c4', 'c13', 'c14', 'c15', 'c16'], ['c5', 'c6', 'c7', 'c8', 'c17', 'c18', 'c19', 'c20'], ['c9', 'c10', 'c11', 'c12', 'c21', 'c22', 'c23', 'c24']]
# Treatment(s): ['one', 'two', 'three'], in [['c1', 'c5', 'c9', 'c13', 'c17', 'c21'], ['c2', 'c6', 'c10', 'c11', 'c14', 'c18', 'c22'], ['c3', 'c4', 'c7', 'c8', 'c12', 'c15', 'c16', 'c19', 'c20', 'c23', 'c24']]
# channel:2 = protein
# cell: 181665
# nucleus: 227607
# pathogen: 695350
# cytoplasm: 181665
# cells: 181665, cells grouped: 181665
# cytoplasms: 181665, cytoplasms grouped: 181665
# nucleus: 227607, nucleus grouped: 181664
# pathogens: 198535, pathogens grouped: 112737
# Generated dataframe with: 791 columns and 112736 rows
# After dropping non-annotated wells: 112736 rows
# ...
