# %%
# Description: Train a ML model to classigy cells based on measurement data
import spacr
from spacr.ml import generate_ml_scores
# %matplotlib inline

srcs = ['/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240810_132824/plate1',
       '/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240824_072829/plate2',
       '/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240825_094106/plate3',
       '/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240826_140251/plate4']

src = ['/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240824_072829/plate2']

settings = {'src':src,
            'model_type_ml':'xgboost',
            'heatmap_feature':'predictions',
            'grouping':'mean',
            'min_max':'allq',
            'cmap':'viridis',
            'n_estimators':1000,
            'test_size':0.1,
            'location_column':'column_name',
            'positive_control':'c2',
            'negative_control':'c1',
            'exclude':None,
            'pathogen_limit':3,
            'nuclei_limit':1,
            'n_repeats':10,
            'reg_alpha':0.1,
            'reg_lambda':1.0,
            'learning_rate':0.001,
            'top_features':30,
            'channel_of_interest':None,
            'minimum_cell_count':0,
            'remove_low_variance_features':True,
            'remove_highly_correlated_features':True,
            'prune_features':False,
            'cross_validation':False,
            'verbose':True,
            'n_jobs':28}

results = spacr.ml.generate_ml_scores(settings)
# Out:
# Models already downloaded to: /home/carruthers/anaconda3/envs/spacr/lib/python3.9/site-packages/spacr/resources/models
#                                   Key  \
# 0                                 src
# 1                       model_type_ml
# 2                     heatmap_feature
# 3                            grouping
# 4                             min_max
# 5                                cmap
# 6                        n_estimators
# 7                           test_size
# 8                     location_column
# 9                    positive_control
# 10                   negative_control
# 11                            exclude
# 12                     pathogen_limit
# 13                       nuclei_limit
# 14                          n_repeats
# 15                          reg_alpha
# 16                         reg_lambda
# 17                      learning_rate
# 18                       top_features
# 19                channel_of_interest
# ...

# %%
# Description: Train a ML model to classigy cells based on measurement data
import spacr
from spacr.ml import generate_ml_scores
# %matplotlib inline

src = ['/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240810_132824/plate1']

settings = {'src':src,
            'model_type_ml':'xgboost',
            'heatmap_feature':'predictions',
            'grouping':'mean',
            'min_max':'allq',
            'cmap':'viridis',
            'n_estimators':1000,
            'test_size':0.1,
            'location_column':'column_name',
            'positive_control':'c2',
            'negative_control':'c1',
            'exclude':None,
            'pathogen_limit':3,
            'nuclei_limit':1,
            'n_repeats':10,
            'reg_alpha':0.1,
            'reg_lambda':1.0,
            'learning_rate':0.001,
            'top_features':30,
            'channel_of_interest':None,
            'minimum_cell_count':0,
            'remove_low_variance_features':True,
            'remove_highly_correlated_features':True,
            'prune_features':False,
            'cross_validation':False,
            'verbose':True,
            'n_jobs':28}

results = spacr.ml.generate_ml_scores(settings)
# Out:
# Models already downloaded to: /home/carruthers/anaconda3/envs/spacr/lib/python3.9/site-packages/spacr/resources/models
#                                   Key  \
# 0                                 src
# 1                       model_type_ml
# 2                     heatmap_feature
# 3                            grouping
# 4                             min_max
# 5                                cmap
# 6                        n_estimators
# 7                           test_size
# 8                     location_column
# 9                    positive_control
# 10                   negative_control
# 11                            exclude
# 12                     pathogen_limit
# 13                       nuclei_limit
# 14                          n_repeats
# 15                          reg_alpha
# 16                         reg_lambda
# 17                      learning_rate
# 18                       top_features
# 19                channel_of_interest
# ...

# %%
src = ['/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240824_072829/plate2']

settings = {'src':src,
            'model_type_ml':'xgboost',
            'heatmap_feature':'predictions',
            'grouping':'mean',
            'min_max':'allq',
            'cmap':'viridis',
            'n_estimators':1000,
            'test_size':0.1,
            'location_column':'column_name',
            'positive_control':'c2',
            'negative_control':'c1',
            'exclude':None,
            'pathogen_limit':3,
            'nuclei_limit':1,
            'n_repeats':10,
            'reg_alpha':0.1,
            'reg_lambda':1.0,
            'learning_rate':0.001,
            'top_features':30,
            'channel_of_interest':None,
            'minimum_cell_count':0,
            'remove_low_variance_features':True,
            'remove_highly_correlated_features':True,
            'prune_features':False,
            'cross_validation':False,
            'verbose':True,
            'n_jobs':28}

results = spacr.ml.generate_ml_scores(settings)
# Out:
#                                   Key  \
# 0                                 src
# 1                       model_type_ml
# 2                     heatmap_feature
# 3                            grouping
# 4                             min_max
# 5                                cmap
# 6                        n_estimators
# 7                           test_size
# 8                     location_column
# 9                    positive_control
# 10                   negative_control
# 11                            exclude
# 12                     pathogen_limit
# 13                       nuclei_limit
# 14                          n_repeats
# 15                          reg_alpha
# 16                         reg_lambda
# 17                      learning_rate
# 18                       top_features
# 19                channel_of_interest
# 20                 minimum_cell_count
# 21       remove_low_variance_features
# 22  remove_highly_correlated_features
# ...

# %%
src = ['/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240825_094106/plate3']

settings = {'src':src,
            'model_type_ml':'xgboost',
            'heatmap_feature':'predictions',
            'grouping':'mean',
            'min_max':'allq',
            'cmap':'viridis',
            'n_estimators':1000,
            'test_size':0.1,
            'location_column':'column_name',
            'positive_control':'c2',
            'negative_control':'c1',
            'exclude':None,
            'pathogen_limit':3,
            'nuclei_limit':1,
            'n_repeats':10,
            'reg_alpha':0.1,
            'reg_lambda':1.0,
            'learning_rate':0.001,
            'top_features':30,
            'channel_of_interest':None,
            'minimum_cell_count':0,
            'remove_low_variance_features':True,
            'remove_highly_correlated_features':True,
            'prune_features':False,
            'cross_validation':False,
            'verbose':True,
            'n_jobs':28}

results = spacr.ml.generate_ml_scores(settings)
# Out:
#                                   Key  \
# 0                                 src
# 1                       model_type_ml
# 2                     heatmap_feature
# 3                            grouping
# 4                             min_max
# 5                                cmap
# 6                        n_estimators
# 7                           test_size
# 8                     location_column
# 9                    positive_control
# 10                   negative_control
# 11                            exclude
# 12                     pathogen_limit
# 13                       nuclei_limit
# 14                          n_repeats
# 15                          reg_alpha
# 16                         reg_lambda
# 17                      learning_rate
# 18                       top_features
# 19                channel_of_interest
# 20                 minimum_cell_count
# 21       remove_low_variance_features
# 22  remove_highly_correlated_features
# ...

# %%
src = ['/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240826_140251/plate4']

settings = {'src':src,
            'model_type_ml':'xgboost',
            'heatmap_feature':'predictions',
            'grouping':'mean',
            'min_max':'allq',
            'cmap':'viridis',
            'n_estimators':1000,
            'test_size':0.1,
            'location_column':'column_name',
            'positive_control':'c2',
            'negative_control':'c1',
            'exclude':None,
            'pathogen_limit':3,
            'nuclei_limit':1,
            'n_repeats':10,
            'reg_alpha':0.1,
            'reg_lambda':1.0,
            'learning_rate':0.001,
            'top_features':30,
            'channel_of_interest':None,
            'minimum_cell_count':0,
            'remove_low_variance_features':True,
            'remove_highly_correlated_features':True,
            'prune_features':False,
            'cross_validation':False,
            'verbose':True,
            'n_jobs':28}

results = spacr.ml.generate_ml_scores(settings)
# Out:
#                                   Key  \
# 0                                 src
# 1                       model_type_ml
# 2                     heatmap_feature
# 3                            grouping
# 4                             min_max
# 5                                cmap
# 6                        n_estimators
# 7                           test_size
# 8                     location_column
# 9                    positive_control
# 10                   negative_control
# 11                            exclude
# 12                     pathogen_limit
# 13                       nuclei_limit
# 14                          n_repeats
# 15                          reg_alpha
# 16                         reg_lambda
# 17                      learning_rate
# 18                       top_features
# 19                channel_of_interest
# 20                 minimum_cell_count
# 21       remove_low_variance_features
# 22  remove_highly_correlated_features
# ...

# %%
# Description: Train a ML model to classigy cells based on measurement data
import spacr
from spacr.ml import generate_ml_scores
# %matplotlib inline

srcs = ['/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240810_132824/plate1',
       '/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240824_072829/plate2',
       '/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240825_094106/plate3',
       '/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240826_140251/plate4']

src1 = ['/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240810_132824/plate1']

src2 = ['/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240824_072829/plate2']

src3 = ['/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240825_094106/plate3']

src4 = ['/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240826_140251/plate4']

srcs = [src1,src2,src3,src4]
for src in srcs:
    settings = {'src':src,
                'model_type_ml':'xgboost',
                'heatmap_feature':'predictions',
                'grouping':'mean',
                'min_max':'allq',
                'cmap':'viridis',
                'n_estimators':1000,
                'test_size':0.1,
                'location_column':'column_name',
                'positive_control':'c2',
                'negative_control':'c1',
                'exclude':None,
                'pathogen_limit':3,
                'nuclei_limit':1,
                'n_repeats':10,
                'reg_alpha':0.1,
                'reg_lambda':1.0,
                'learning_rate':0.001,
                'top_features':30,
                'channel_of_interest':None,
                'minimum_cell_count':0,
                'remove_low_variance_features':True,
                'remove_highly_correlated_features':True,
                'prune_features':False,
                'cross_validation':False,
                'verbose':True,
                'n_jobs':28}

    results = spacr.ml.generate_ml_scores(settings)

# %%
# Description: Train a ML model to classigy cells based on measurement data
import spacr
from spacr.ml import generate_ml_scores
# %matplotlib inline

settings = {'src':'/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240810_132824/plate1',
            'model_type_ml':'xgboost',
            'heatmap_feature':'predictions',
            'grouping':'mean',
            'min_max':'allq',
            'cmap':'viridis',
            'n_estimators':1000,
            'test_size':0.1,
            'location_column':'column_name',
            'positive_control':'c2',
            'negative_control':'c1',
            'exclude':None,
            'pathogen_limit':3,
            'nuclei_limit':1,
            'n_repeats':10,
            'reg_alpha':0.1,
            'reg_lambda':1.0,
            'learning_rate':0.001,
            'top_features':30,
            'channel_of_interest':1,
            'minimum_cell_count':0,
            'remove_low_variance_features':True,
            'remove_highly_correlated_features':True,
            'prune_features':False,
            'cross_validation':True,
            'verbose':True,
            'n_jobs':28}

results = spacr.ml.generate_ml_scores(settings)

# %%
srcs  = ['/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240810_132824/plate1',
        '/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240824_072829/plate2',
        '/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240825_094106/plate3',
        '/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240826_140251/plate4']

for src in srcs:
    settings['src'] = src
    for channel_of_interest in [None, 0,1,2,3, [0,1], [0,2],[0,3],[1,2],[1,3],[2,3],[0,1,2],[1,2,3], 'morphology']:
        settings['channel_of_interest'] = channel_of_interest
        results = spacr.ml.generate_ml_scores(settings)

# %%
import spacr
from spacr.ml import generate_ml_scores
# %matplotlib inline

settings = {'src':'/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240810_132824/plate1',
            'model_type_ml':'xgboost',
            'heatmap_feature':'predictions',
            'grouping':'mean',
            'min_max':'allq',
            'cmap':'viridis',
            'n_estimators':1000,
            'test_size':0.1,
            'location_column':'column_name',
            'positive_control':'c2',
            'negative_control':'c1',
            'exclude':None,
            'pathogen_limit':3,
            'nuclei_limit':1,
            'n_repeats':10,
            'reg_alpha':0.1,
            'reg_lambda':1.0,
            'learning_rate':0.001,
            'top_features':30,
            'channel_of_interest':1,
            'minimum_cell_count':0,
            'remove_low_variance_features':True,
            'remove_highly_correlated_features':True,
            'prune_features':False,
            'cross_validation':True,
            'verbose':False,
            'n_jobs':28}

srcs  = ['/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240810_132824/plate1',
        '/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240824_072829/plate2',
        '/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240825_094106/plate3',
        '/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240826_140251/plate4']

for src in srcs:
    settings['src'] = src
    for channel_of_interest in [1]:
        settings['channel_of_interest'] = channel_of_interest
        results = spacr.ml.generate_ml_scores(settings)

# %%
# Description: Fix a regression model to estimate the effect size of gRNAs on cell scores.

from spacr.ml import perform_regression
import pandas as pd
# %matplotlib inline

settings = {'count_data':'path',
            'score_data':'path',
            'highlight':'string',
            'fraction_threshold':0.1,
            'dependent_variable': 'prediction_probability_class_1',
            'transform':'log',
            'agg_type':'median',
            'min_cell_count':25,
            'regression_type':'ols',
            'random_row_column_effects':False,
            'plate':None,
            'cov_type':None,
            'alpha':0.8,
            'nc':'c1',
            'pc':'c2',
            'other':'c3'}

coef_df = perform_regression(settings)
