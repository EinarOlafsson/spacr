# %%
srcs = ['/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240810_132824/plate1',
       '/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240824_072829/plate2',
       '/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240825_094106/plate3',
       '/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240826_140251/plate4']

settings = {'src':srcs,
            'model_type_ml':'xgboost',
            'heatmap_feature':'predictions',
            'grouping':'mean',
            'min_max':'allq',
            'cmap':'viridis',
            'n_estimators':1000,
            'test_size':0.1,
            'location_column':'column_name',
            'positive_control':'c2',
            'negative_control':'c1',
            'exclude':None,
            'pathogen_limit':3,
            'nuclei_limit':1,
            'n_repeats':10,
            'reg_alpha':0.1,
            'reg_lambda':1.0,
            'learning_rate':0.001,
            'top_features':30,
            'channel_of_interest':0,
            'minimum_cell_count':0,
            'remove_low_variance_features':True,
            'remove_highly_correlated_features':True,
            'prune_features':False,
            'cross_validation':False,
            'verbose':True,
            'n_jobs':28}

results = spacr.ml.generate_ml_scores(settings)
# Out:
#                                   Key  \
# 0                                 src
# 1                       model_type_ml
# 2                     heatmap_feature
# 3                            grouping
# 4                             min_max
# 5                                cmap
# 6                        n_estimators
# 7                           test_size
# 8                     location_column
# 9                    positive_control
# 10                   negative_control
# 11                            exclude
# 12                     pathogen_limit
# 13                       nuclei_limit
# 14                          n_repeats
# 15                          reg_alpha
# 16                         reg_lambda
# 17                      learning_rate
# 18                       top_features
# 19                channel_of_interest
# 20                 minimum_cell_count
# 21       remove_low_variance_features
# 22  remove_highly_correlated_features
# ...

# %%
# Description: Train a ML model to classigy cells based on measurement data
import spacr
from spacr.ml import generate_ml_scores
# %matplotlib inline

srcs = ['/nas_mnt/carruthers/Einar/tsg101_screen/hits_20250102_220732/plate1']
#srcs = ['/nas_mnt/carruthers/Einar/tsg101_screen/hits_20250108_181547/plate2']

settings = {'src':srcs,
            'model_type_ml':'xgboost',
            'heatmap_feature':'prediction_probability_class_1',
            'grouping':'mean',
            'min_max':'allq',
            'cmap':'viridis',
            'n_estimators':1000,
            'test_size':0.1,
            'location_column':'column_name',
            'positive_control':['c23','c24'],
            'negative_control':['c21', 'c22'],
            'exclude':None,
            'pathogen_limit':3,
            'nuclei_limit':1,
            'n_repeats':100,
            'reg_alpha':0.1,
            'reg_lambda':1.0,
            'learning_rate':0.001,
            'top_features':30,
            'channel_of_interest':1,
            'minimum_cell_count':0,
            'remove_low_variance_features':True,
            'remove_highly_correlated_features':True,
            'prune_features':False,
            'cross_validation':False,
            'verbose':True,
            'n_jobs':28}

results = spacr.ml.generate_ml_scores(settings)
# Out:
# Models already downloaded to: /home/carruthers/anaconda3/envs/spacr/lib/python3.9/site-packages/spacr/resources/models
#                                   Key  \
# 0                                 src
# 1                       model_type_ml
# 2                     heatmap_feature
# 3                            grouping
# 4                             min_max
# 5                                cmap
# 6                        n_estimators
# 7                           test_size
# 8                     location_column
# 9                    positive_control
# 10                   negative_control
# 11                            exclude
# 12                     pathogen_limit
# 13                       nuclei_limit
# 14                          n_repeats
# 15                          reg_alpha
# 16                         reg_lambda
# 17                      learning_rate
# 18                       top_features
# 19                channel_of_interest
# ...

# %%
# Description: Generate train and test folders with class subfolders for training DL models.
from spacr.io import generate_training_dataset

settings = {'src':'/nas_mnt/carruthers/Einar/tsg101_screen/hits_20250108_181547/plate2',
            'dataset_mode':'metadata',
            'test_split':0.1,
            'metadata_type_by':'col',
            'class_metadata':['nc','pc'],
            'metadata_item_1_name':['nc', 'pc'],
            'metadata_item_1_value':[['c18'], ['c19']],
            'metadata_item_2_name':None,
            'metadata_item_2_value':None,
            'png_type':'cell_png',
            'nuclei_limit':1,
            'pathogen_limit':3,
            'uninfected':False,
            'size':None}

generate_training_dataset(settings)
# Out:
#                       Key                                              Value
# 0                     src  /nas_mnt/carruthers/Einar/tsg101_screen/hits_2...
# 1            dataset_mode                                           metadata
# 2              test_split                                                0.1
# 3        metadata_type_by                                                col
# 4          class_metadata                                           [nc, pc]
# 5    metadata_item_1_name                                           [nc, pc]
# 6   metadata_item_1_value                                     [[c18], [c19]]
# 7    metadata_item_2_name                                               None
# 8   metadata_item_2_value                                               None
# 9                png_type                                           cell_png
# 10           nuclei_limit                                                  1
# ...

# %%
# Description: Train a torch model to classify single object images
from spacr.deep_spacr import train_test_model

settings = {'src':'/nas_mnt/carruthers/Einar/tsg101_screen/hits_20250108_181547/plate2/datasets/training', 
            'train':False,
            'test': True,
            'custom_model':'/nas_mnt/carruthers/Einar/tsg101_screen/hits_20250108_181547/plate2/datasets/training/model/maxvit_t/rgb/epochs_100/maxvit_t_epoch_100_channels_rgb.pth',
            'custom_model_path':None,
            'classes':['nc','pc'],
            'model_type':'maxvit_t',
            'optimizer_type':'adamw',
            'schedule':'reduce_lr_on_plateau', #reduce_lr_on_plateau, step_lr
            'loss_type':'focal_loss', #binary_cross_entropy_with_logits, #focal_loss
            'normalize':True,
            'image_size':224,
            'batch_size':64,
            'epochs':100,
            'val_split':0.1,
            'learning_rate':0.0001,
            'weight_decay':0.00001,
            'dropout_rate':0.1,
            'init_weights':True,
            'amsgrad':True,
            'use_checkpoint':True,
            'gradient_accumulation':True,
            'gradient_accumulation_steps':4,
            'intermedeate_save':True,
            'pin_memory':True,
            'n_jobs':30,
            'train_channels':['r','g','b'],
            'augment':True,
            'verbose':True}

train_test_model(settings)
# Out:
# Training a network on channels: [1, 2, 3]
# Channel 1: Red, Channel 2: Green, Channel 3: Blue
# Loading test dataset
# Results wil be saved in: /nas_mnt/carruthers/Einar/tsg101_screen/hits_20250108_181547/plate2/datasets/training/model/maxvit_t/rgb/epochs_100/maxvit_t_time_250117_test_result.csv
# Copied 9 misclassified images.
# '/nas_mnt/carruthers/Einar/tsg101_screen/hits_20250108_181547/plate2/datasets/training/model/maxvit_t/rgb/epochs_100/maxvit_t_time_250117_test_result.csv'

# %%
# Description: Generate a tar file containing single object images.
from spacr.io import generate_dataset

settings = {'src':'/nas_mnt/carruthers/Einar/tsg101_screen/hits_20250108_181547/plate2',
           'file_metadata':None,
           'experiment':'tsg101_screen_hits_plate1',
           'sample':None}

generate_dataset(settings)
# Out:
#              Key                                              Value
# 0            src  /nas_mnt/carruthers/Einar/tsg101_screen/hits_2...
# 1  file_metadata                                               None
# 2     experiment                          tsg101_screen_hits_plate1
# 3         sample                                               None
# Reading DataBase: /nas_mnt/carruthers/Einar/tsg101_screen/hits_20250108_181547/plate2/measurements/measurements.db
# All paths: 14787 paths
# Found 14787 images
# Generating temporary tar files in /nas_mnt/carruthers/Einar/tsg101_screen/hits_20250108_181547/plate2/datasets
# Progress: 10/14787, operation_type: generating .tar dataset, None
# Progress: 20/14787, operation_type: generating .tar dataset, None
# Progress: 30/14787, operation_type: generating .tar dataset, None
# Progress: 40/14787, operation_type: generating .tar dataset, None
# Progress: 50/14787, operation_type: generating .tar dataset, None
# ...

# %%
# Description: Classify images in a tar dataset with a trained torch model.
from spacr.deep_spacr import apply_model_to_tar

settings = {'tar_path':'/nas_mnt/carruthers/Einar/tsg101_screen/hits_20250108_181547/plate2/datasets/250117_tsg101_screen_hits_plate2.tar',
            'model_path':'/nas_mnt/carruthers/Einar/tsg101_screen/hits_20250108_181547/plate2/datasets/training/model/maxvit_t/rgb/epochs_100/maxvit_t_epoch_100_channels_rgb.pth', 
            'file_type':'cell_png',
            'image_size':224,
            'batch_size':64,
            'normalize':True,
            'score_threshold':0.5,
            'n_jobs':30,
            'verbose':True}

result_df = apply_model_to_tar(settings)
# Out:
# Loading model from /nas_mnt/carruthers/Einar/tsg101_screen/hits_20250108_181547/plate2/datasets/training/model/maxvit_t/rgb/epochs_100/maxvit_t_epoch_100_channels_rgb.pth
# Loading dataset from /nas_mnt/carruthers/Einar/tsg101_screen/hits_20250108_181547/plate2/datasets/250117_tsg101_screen_hits_plate2.tar
# TorchModel(
#   (base_model): MaxVit(
#     (stem): Sequential(
#       (0): Conv2dNormActivation(
#         (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (2): GELU(approximate='none')
#       )
#       (1): Conv2dNormActivation(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#     (blocks): ModuleList(
#       (0): MaxVitBlock(
#         (layers): ModuleList(
#           (0): MaxVitLayer(
#             (layers): Sequential(
#               (MBconv): MBConv(
# ...

# %%
# Description: Train a torch model to classify single object images
from spacr.deep_spacr import train_test_model

settings = {'src':'/nas_mnt/carruthers/Einar/tsg101_screen/hits_20250102_220732/plate1/datasets/training', 
            'train':False,
            'test': True,
            'custom_model':'/nas_mnt/carruthers/Einar/tsg101_screen/hits_20250102_220732/plate1/datasets/training/model/maxvit_t/rgb/epochs_100/maxvit_t_epoch_100_channels_rgb.pth',
            'custom_model_path':'/nas_mnt/carruthers/Einar/tsg101_screen/hits_20250102_220732/plate1/datasets/training/model/maxvit_t/rgb/epochs_100/maxvit_t_epoch_100_channels_rgb.pth',
            'classes':['nc','pc'],
            'model_type':'maxvit_t',
            'optimizer_type':'adamw',
            'schedule':'reduce_lr_on_plateau', #reduce_lr_on_plateau, step_lr
            'loss_type':'focal_loss', #binary_cross_entropy_with_logits, #focal_loss
            'normalize':True,
            'image_size':224,
            'batch_size':64,
            'epochs':100,
            'val_split':0.1,
            'learning_rate':0.0001,
            'weight_decay':0.00001,
            'dropout_rate':0.1,
            'init_weights':True,
            'amsgrad':True,
            'use_checkpoint':True,
            'gradient_accumulation':True,
            'gradient_accumulation_steps':4,
            'intermedeate_save':True,
            'pin_memory':True,
            'n_jobs':30,
            'train_channels':['r','g','b'],
            'augment':True,
            'verbose':True}

train_test_model(settings)
# Out:
# Training a network on channels: [1, 2, 3]
# Channel 1: Red, Channel 2: Green, Channel 3: Blue
# Loading test dataset
# Results wil be saved in: /nas_mnt/carruthers/Einar/tsg101_screen/hits_20250102_220732/plate1/datasets/training/model/maxvit_t/rgb/epochs_100/maxvit_t_time_250117_test_result.csv
# Copied 7 misclassified images.
# '/nas_mnt/carruthers/Einar/tsg101_screen/hits_20250102_220732/plate1/datasets/training/model/maxvit_t/rgb/epochs_100/maxvit_t_time_250117_test_result.csv'

# %%
#/nas_mnt/carruthers/Einar/tsg101_screen/hits_20250118_110723/plate3

# Description: Generate a tar file containing single object images.
from spacr.io import generate_dataset

settings = {'src':'/nas_mnt/carruthers/Einar/tsg101_screen/hits_20250118_110723/plate3',
           'file_metadata':None,
           'experiment':'tsg101_screen_plate3',
           'sample':None}

generate_dataset(settings)
# Out:
# Models already downloaded to: /home/carruthers/anaconda3/envs/spacr/lib/python3.9/site-packages/spacr/resources/models
#              Key                                              Value
# 0            src  /nas_mnt/carruthers/Einar/tsg101_screen/hits_2...
# 1  file_metadata                                               None
# 2     experiment                               tsg101_screen_plate3
# 3         sample                                               None
# Reading DataBase: /nas_mnt/carruthers/Einar/tsg101_screen/hits_20250118_110723/plate3/measurements/measurements.db
# All paths: 103792 paths
# Found 103792 images
# Generating temporary tar files in /nas_mnt/carruthers/Einar/tsg101_screen/hits_20250118_110723/plate3/datasets
# Progress: 10/103792, operation_type: generating .tar dataset, None
# Progress: 20/103792, operation_type: generating .tar dataset, None
# Progress: 30/103792, operation_type: generating .tar dataset, None
# ...

# %%
# Description: Classify images in a tar dataset with a trained torch model.
from spacr.deep_spacr import apply_model_to_tar

settings = {'tar_path':'/nas_mnt/carruthers/Einar/tsg101_screen/hits_20250118_110723/plate3/datasets/250123_tsg101_screen_plate3.tar',
            'model_path':'/nas_mnt/carruthers/Einar/tsg101_screen/hits_20250102_220732/plate1/combined_model.pth', 
            'file_type':'cell_png',
            'image_size':224,
            'batch_size':64,
            'normalize':True,
            'score_threshold':0.5,
            'n_jobs':30,
            'verbose':True}

result_df = apply_model_to_tar(settings)
# Out:
# Loading model from /nas_mnt/carruthers/Einar/tsg101_screen/hits_20250102_220732/plate1/combined_model.pth
# Loading dataset from /nas_mnt/carruthers/Einar/tsg101_screen/hits_20250118_110723/plate3/datasets/250123_tsg101_screen_plate3.tar
# TorchModel(
#   (base_model): MaxVit(
#     (stem): Sequential(
#       (0): Conv2dNormActivation(
#         (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (2): GELU(approximate='none')
#       )
#       (1): Conv2dNormActivation(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#     (blocks): ModuleList(
#       (0): MaxVitBlock(
#         (layers): ModuleList(
#           (0): MaxVitLayer(
#             (layers): Sequential(
#               (MBconv): MBConv(
#                 (proj): Sequential(
# ...

# %%
# Description: Generate a tar file containing single object images.
from spacr.io import generate_dataset

settings = {'src':'/nas_mnt/carruthers/Einar/tsg101_screen/hits_20250102_220732/plate1',
           'file_metadata':None,
           'experiment':'tsg101_screen_plate1',
           'sample':None}

generate_dataset(settings)
# Out:
#              Key                                              Value
# 0            src  /nas_mnt/carruthers/Einar/tsg101_screen/hits_2...
# 1  file_metadata                                               None
# 2     experiment                               tsg101_screen_plate1
# 3         sample                                               None
# Reading DataBase: /nas_mnt/carruthers/Einar/tsg101_screen/hits_20250102_220732/plate1/measurements/measurements.db
# All paths: 61560 paths
# Found 61560 images
# Generating temporary tar files in /nas_mnt/carruthers/Einar/tsg101_screen/hits_20250102_220732/plate1/datasets
# Progress: 10/61560, operation_type: generating .tar dataset, None
# Progress: 20/61560, operation_type: generating .tar dataset, None
# Progress: 30/61560, operation_type: generating .tar dataset, None
# Progress: 40/61560, operation_type: generating .tar dataset, None
# Progress: 50/61560, operation_type: generating .tar dataset, None
# ...

# %%
# Description: Classify images in a tar dataset with a trained torch model.
from spacr.deep_spacr import apply_model_to_tar

settings = {'tar_path':'/nas_mnt/carruthers/Einar/tsg101_screen/hits_20250108_181547/plate2/datasets/250117_tsg101_screen_hits_plate2.tar',
            'model_path':'/nas_mnt/carruthers/Einar/tsg101_screen/hits_20250102_220732/plate1/combined_model.pth', 
            'file_type':'cell_png',
            'image_size':224,
            'batch_size':64,
            'normalize':True,
            'score_threshold':0.5,
            'n_jobs':30,
            'verbose':True}

result_df = apply_model_to_tar(settings)
# Out:
# Loading model from /nas_mnt/carruthers/Einar/tsg101_screen/hits_20250102_220732/plate1/combined_model.pth
# Loading dataset from /nas_mnt/carruthers/Einar/tsg101_screen/hits_20250108_181547/plate2/datasets/250117_tsg101_screen_hits_plate2.tar
# TorchModel(
#   (base_model): MaxVit(
#     (stem): Sequential(
#       (0): Conv2dNormActivation(
#         (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (2): GELU(approximate='none')
#       )
#       (1): Conv2dNormActivation(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#     (blocks): ModuleList(
#       (0): MaxVitBlock(
#         (layers): ModuleList(
#           (0): MaxVitLayer(
#             (layers): Sequential(
#               (MBconv): MBConv(
#                 (proj): Sequential(
# ...

# %%
# FIG2E
# %matplotlib inline
import matplotlib.pyplot as plt
from spacr.plot import plot_data_from_csv
import os

srcs_train = ['/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240810_132824/plate1/datasets/training/model/maxvit_t/rgb/epochs_100/train.csv',
              '/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240824_072829/plate2/datasets/training/model/maxvit_t/rgb/epochs_100/train.csv',
              '/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240825_094106/plate3/datasets/training/model/maxvit_t/rgb/epochs_100/train.csv',
              '/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240826_140251/plate4/datasets/training/model/maxvit_t/rgb/epochs_100/train.csv']

srcs_valid = ['/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240810_132824/plate1/datasets/training/model/maxvit_t/rgb/epochs_100/validation.csv',
              '/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240824_072829/plate2/datasets/training/model/maxvit_t/rgb/epochs_100/validation.csv',
              '/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240825_094106/plate3/datasets/training/model/maxvit_t/rgb/epochs_100/validation.csv',
              '/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240826_140251/plate4/datasets/training/model/maxvit_t/rgb/epochs_100/validation.csv']

srcs_all = ['/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240810_132824/plate1/datasets/training/model/maxvit_t/rgb/epochs_100/train.csv',
            '/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240824_072829/plate2/datasets/training/model/maxvit_t/rgb/epochs_100/train.csv',
            '/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240825_094106/plate3/datasets/training/model/maxvit_t/rgb/epochs_100/train.csv',
            '/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240826_140251/plate4/datasets/training/model/maxvit_t/rgb/epochs_100/train.csv',
            '/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240810_132824/plate1/datasets/training/model/maxvit_t/rgb/epochs_100/validation.csv',
            '/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240824_072829/plate2/datasets/training/model/maxvit_t/rgb/epochs_100/validation.csv',
            '/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240825_094106/plate3/datasets/training/model/maxvit_t/rgb/epochs_100/validation.csv',
            '/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240826_140251/plate4/datasets/training/model/maxvit_t/rgb/epochs_100/validation.csv']

srcs_hits = ['/nas_mnt/carruthers/Einar/tsg101_screen/hits_20250102_220732/plate1/datasets/250117_250117_tsg101_screen_hits_plate1_maxvit_t_epoch_100_channels_rgb_result.csv']
#srcs_hits = ['/nas_mnt/carruthers/Einar/tsg101_screen/hits_20250108_181547/plate2/datasets/250117_250117_tsg101_screen_hits_plate2_maxvit_t_epoch_100_channels_rgb_result.csv']
srcs_hits = ['/nas_mnt/carruthers/Einar/tsg101_screen/hits_20250102_220732/plate1/datasets/250117_250117_tsg101_screen_hits_plate1_combined_model_result.csv']
srcs_hits = ['/nas_mnt/carruthers/Einar/tsg101_screen/hits_20250102_220732/plate1/datasets/250117_250117_tsg101_screen_hits_plate1_combined_model_result_filter.csv']
srcs_hits = ['/nas_mnt/carruthers/Einar/tsg101_screen/hits_20250102_220732/plate1/datasets/250117_250117_tsg101_screen_hits_plate1_combined_model_result_filter.csv']
srcs_hits = ['/nas_mnt/carruthers/Einar/tsg101_screen/hits_20250108_181547/plate2/datasets/250117_250117_tsg101_screen_hits_plate2_maxvit_t_epoch_100_channels_rgb_result_filter.csv']
srcs_hits = ['/nas_mnt/carruthers/Einar/tsg101_screen/hits_20250108_181547/plate2/datasets/250117_250117_tsg101_screen_hits_plate2_combined_model_result.csv']
srcs_hits = ['/nas_mnt/carruthers/Einar/tsg101_screen/hits_20250108_181547/plate2/datasets/250117_250117_tsg101_screen_hits_plate2_combined_model_result_filter.csv']
srcs_hits = ['/nas_mnt/carruthers/Einar/tsg101_screen/hits_20250118_110723/plate3/datasets/250123_250123_tsg101_screen_plate3_combined_model_result.csv']

srcs_hits = ['/nas_mnt/carruthers/Einar/tsg101_screen/hits_20250102_220732/plate1/datasets/250117_250117_tsg101_screen_hits_plate1_combined_model_result_filter.csv',
             '/nas_mnt/carruthers/Einar/tsg101_screen/hits_20250118_110723/plate3/datasets/250123_250123_tsg101_screen_plate3_combined_model_result_filter.csv',
             '/nas_mnt/carruthers/Einar/tsg101_screen/hits_20250108_181547/plate2/datasets/250117_250117_tsg101_screen_hits_plate2_combined_model_result.csv']

settings = {'src':srcs_hits,
            'graph_name':'fig2d_valid_acc',
            'data_column':['pred'],
            'grouping_column':'column',
            'graph_type':'box',
            'theme':'bright',
            'save':True,
            'y_lim':[None, None],
            'log_y':False,
            'log_x':False,
            'representation':'plate',
            'verbose':True}

fig,df = plot_data_from_csv(settings)
plt.show()
display(df)
# Out:
#        Unnamed: 0                  path      pred    plate row_name column  \
# 0              13   plate1_I01_1_25.png  0.805446  pplate1       r9     c1
# 1              23  plate1_D18_12_51.png  0.197235  pplate1       r4    c18
# 2              26   plate1_D21_7_29.png  0.849952  pplate1       r4    c21
# 3              33  plate1_C18_12_55.png  0.180801  pplate1       r3    c18
# 4              37   plate1_H19_2_78.png  0.126231  pplate1       r8    c19
# ...           ...                   ...       ...      ...      ...    ...
# 14782       14782   plate2_F06_12_3.png  0.449967  pplate2       r6     c6
# 14783       14783   plate2_F06_10_7.png  0.544486  pplate2       r6     c6
# 14784       14784    plate2_E16_4_7.png  0.279021  pplate2       r5    c16
# 14785       14785   plate2_B05_11_2.png  0.302726  pplate2       r2     c5
# 14786       14786   plate2_F09_4_22.png  0.433671  pplate2       r6     c9
#
#       field  object             prc  cv_predictions column_name
# ...

# %%
import pandas as pd

def filter_and_save_csv(input_csv, output_csv, column_name, upper_threshold, lower_threshold):
    """
    Reads a CSV into a DataFrame, filters rows based on a column for values > upper_threshold and < lower_threshold,
    and saves the filtered DataFrame to a new CSV file.

    Parameters:
        input_csv (str): Path to the input CSV file.
        output_csv (str): Path to save the filtered CSV file.
        column_name (str): Column name to apply the filters on.
        upper_threshold (float): Upper threshold for filtering (values greater than this are retained).
        lower_threshold (float): Lower threshold for filtering (values less than this are retained).

    Returns:
        None
    """
    # Read the input CSV file into a DataFrame
    df = pd.read_csv(input_csv)

    # Filter rows based on the thresholds
    filtered_df = df[(df[column_name] > upper_threshold) | (df[column_name] < lower_threshold)]

    # Save the filtered DataFrame to a new CSV file
    filtered_df.to_csv(output_csv, index=False)
    display(filtered_df)

    print(f"Filtered DataFrame saved to {output_csv}")
    
input_csv = '/nas_mnt/carruthers/Einar/tsg101_screen/hits_20250118_110723/plate3/datasets/250123_250123_tsg101_screen_plate3_combined_model_result.csv'
output_csv = '/nas_mnt/carruthers/Einar/tsg101_screen/hits_20250118_110723/plate3/datasets/250123_250123_tsg101_screen_plate3_combined_model_result_filter.csv'
column_name = 'pred'
upper_threshold = 0.8
lower_threshold = 0.2
filter_and_save_csv(input_csv, output_csv, column_name, upper_threshold, lower_threshold)
# Out:
#         Unnamed: 0                   path      pred    plate row_name column  \
# 3                3   plate3_C04_10_43.png  0.187955  pplate3       r3     c4
# 4                4   plate3_O15_12_52.png  0.194175  pplate3      r15    c15
# 5                5    plate3_E17_4_46.png  0.176217  pplate3       r5    c17
# 8                8    plate3_P19_1_36.png  0.896667  pplate3      r16    c19
# 9                9    plate3_N19_3_95.png  0.840154  pplate3      r14    c19
# ...            ...                    ...       ...      ...      ...    ...
# 103778      103778   plate3_A11_9_142.png  0.180803  pplate3       r1    c11
# 103780      103780   plate3_H12_5_144.png  0.176312  pplate3       r8    c12
# 103781      103781    plate3_N11_5_29.png  0.177558  pplate3      r14    c11
# 103784      103784    plate3_G19_3_36.png  0.870979  pplate3       r7    c19
# 103790      103790  plate3_J04_11_103.png  0.144218  pplate3      r10     c4
#
# ...

# %%
#srcs_hits = ['/nas_mnt/carruthers/Einar/tsg101_screen/hits_20250108_181547/plate2/datasets/250117_250117_tsg101_screen_hits_plate2_maxvit_t_epoch_100_channels_rgb_result.csv']
srcs_hits = ['/nas_mnt/carruthers/Einar/tsg101_screen/hits_20250102_220732/plate1/datasets/250117_250117_tsg101_screen_hits_plate1_combined_model_result.csv']
settings = {'src':srcs_hits,
            'graph_name':'fig2d_valid_acc',
            'data_column':['pred'],
            'grouping_column':'column',
            'graph_type':'jitter_bar',
            'theme':'bright',
            'save':True,
            'y_lim':[None, None],
            'log_y':False,
            'log_x':False,
            'representation':'well',
            'verbose':True}

fig,df = plot_data_from_csv(settings)
plt.show()
display(df)
# Out:
#        Unnamed: 0                  path      pred    plate row_name column  \
# 0               0   plate1_G13_1_14.png  0.208775  pplate1       r7    c13
# 1               1  plate1_H19_3_361.png  0.548756  pplate1       r8    c19
# 2               2  plate1_C06_10_10.png  0.422083  pplate1       r3     c6
# 3               3  plate1_D20_11_17.png  0.373633  pplate1       r4    c20
# 4               4    plate1_E17_3_2.png  0.453268  pplate1       r5    c17
# ...           ...                   ...       ...      ...      ...    ...
# 61555       61555    plate1_D12_4_1.png  0.664941  pplate1       r4    c12
# 61556       61556   plate1_G13_4_20.png  0.268939  pplate1       r7    c13
# 61557       61557   plate1_H14_8_89.png  0.600210  pplate1       r8    c14
# 61558       61558  plate1_H01_10_53.png  0.432169  pplate1       r8     c1
# 61559       61559    plate1_A04_9_2.png  0.343484  pplate1       r1     c4
#
#       field  object             prc  cv_predictions column_name
# ...

# %%
# Description: Classify images in a tar dataset with a trained torch model.
from spacr.deep_spacr import apply_model_to_tar

settings = {'tar_path':'/nas_mnt/carruthers/Einar/tsg101_screen/hits_20250102_220732/plate1/datasets/250117_tsg101_screen_hits_plate1.tar',
            'model_path':'/nas_mnt/carruthers/Einar/tsg101_screen/hits_20250102_220732/plate1/combined_model.pth', 
            'file_type':'cell_png',
            'image_size':224,
            'batch_size':64,
            'normalize':True,
            'score_threshold':0.5,
            'n_jobs':30,
            'verbose':True}

result_df = apply_model_to_tar(settings)
# Out:
# Loading model from /nas_mnt/carruthers/Einar/tsg101_screen/hits_20250102_220732/plate1/combined_model.pth
# Loading dataset from /nas_mnt/carruthers/Einar/tsg101_screen/hits_20250102_220732/plate1/datasets/250117_tsg101_screen_hits_plate1.tar
# TorchModel(
#   (base_model): MaxVit(
#     (stem): Sequential(
#       (0): Conv2dNormActivation(
#         (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (2): GELU(approximate='none')
#       )
#       (1): Conv2dNormActivation(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#     (blocks): ModuleList(
#       (0): MaxVitBlock(
#         (layers): ModuleList(
#           (0): MaxVitLayer(
#             (layers): Sequential(
#               (MBconv): MBConv(
#                 (proj): Sequential(
# ...
