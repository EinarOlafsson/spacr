# %%
# Description: use this cell to generate train and test folders: datasets/train/nc and pc and datasets/test/nc and pc
from spacr.io import generate_training_dataset

settings = {'src':'/nas_mnt/carruthers/sophia/BIS009_20240701_102850/PECCU', # (path) path to source folder (where origional images were stored)
            'dataset_mode':'metadata', # (string) annotation, measurement, metadata, annotation_metadata
            'tables':['cell'],# (list of strings) The tabels present in the database, excluding png_list
            'test_split':0.1, # (float) Fraction of images used for the test set
            'annotation_column':'test', # (Optional, string) If using mode annotation, The annotation column in the database
            'annotated_classes':[1], # (Optional, list of integers) If using mode annotation, The interger in annotation_column, if len(annotated_classes) is 1, class 2 will be generated from a random selection of images.
            'metadata_item_1_name':['nc','pc'], # (Optional, string) If using mode medatada, First metadata name list
            'metadata_item_1_value':[['c19','c2'],['c3','c4']], # (Optional, string) If using mode medatada, First metadata value list of lists
            'metadata_item_2_name':['sample1','sample2'], # (Optional, string) If using mode medatada, First metadata name list
            'metadata_item_2_value':[['r1','r2'],['r3','r4']], # (Optional, string) If using mode medatada, Second metadata value list of lists
            'metadata_type_by':'condition', # (Optional, string) If using mode medatada, If using mode medatada,the column class_metadata elements are in
            'class_metadata':['nc_sample1','pc_sample1'], # (Optional, list of lists of strings) If using mode medatada, the elements that deffine each class 
            'png_type':'cell_png', # (Optional, string) string in the path of each image (used to filter images)
            'nuclei_limit':False, # (Optional, bool) if cell and nucleus in tables, filter for number of nuclei per cell
            'pathogen_limit':0, # (Optional, integer) if cell and pathogen in tables, filter for number of pathogen per cell
            'uninfected':True, # (Optional, bool) if cell and pathogen in tables, bool for uninfected cells (cells)
            'size':None # (Optional, integer or NoneType) limit for number of images to include in total (test + train) per class
           }

generate_training_dataset(settings)
# Out:
# Models already downloaded to: /home/carruthers/anaconda3/envs/spacr/lib/python3.9/site-packages/spacr/resources/models
#                       Key                                              Value
# 0                     src  /nas_mnt/carruthers/sophia/BIS009_20240701_102...
# 1            dataset_mode                                           metadata
# 2                  tables                                             [cell]
# 3              test_split                                                0.1
# 4       annotation_column                                               test
# 5       annotated_classes                                                [1]
# 6    metadata_item_1_name                                           [nc, pc]
# 7   metadata_item_1_value                              [[c19, c2], [c3, c4]]
# 8    metadata_item_2_name                                 [sample1, sample2]
# 9   metadata_item_2_value                               [[r1, r2], [r3, r4]]
# 10       metadata_type_by                                          condition
# 11         class_metadata                           [nc_sample1, pc_sample1]
# 12               png_type                                           cell_png
# 13           nuclei_limit                                              False
# 14         pathogen_limit                                                  0
# 15             uninfected                                               True
# 16                   size                                               None
# 17    channel_of_interest                                                  3
# 18     custom_measurement                                               None
#                                                  png_path  \
# 0       /nas_mnt/carruthers/sophia/BIS009_20240701_102...
# 1       /nas_mnt/carruthers/sophia/BIS009_20240701_102...
# 2       /nas_mnt/carruthers/sophia/BIS009_20240701_102...
# 3       /nas_mnt/carruthers/sophia/BIS009_20240701_102...
# 4       /nas_mnt/carruthers/sophia/BIS009_20240701_102...
# ...                                                   ...
# 499989  /nas_mnt/carruthers/sophia/BIS009_20240701_102...
# 499990  /nas_mnt/carruthers/sophia/BIS009_20240701_102...
# 499991  /nas_mnt/carruthers/sophia/BIS009_20240701_102...
# 499992  /nas_mnt/carruthers/sophia/BIS009_20240701_102...
# 499993  /nas_mnt/carruthers/sophia/BIS009_20240701_102...
#
#                   file_name   plate row_name column_name field  \
# 0         PECCU_B19_1_1.png  pPECCU       r2         c19    f1
# 1         PECCU_B19_1_2.png  pPECCU       r2         c19    f1
# 2         PECCU_B19_1_3.png  pPECCU       r2         c19    f1
# 3         PECCU_B19_1_4.png  pPECCU       r2         c19    f1
# 4         PECCU_B19_1_5.png  pPECCU       r2         c19    f1
# ...                     ...     ...      ...         ...   ...
# 499989  PECCU_D15_5_224.png  pPECCU       r4         c15    f5
# 499990  PECCU_D15_5_225.png  pPECCU       r4         c15    f5
# 499991  PECCU_D15_5_226.png  pPECCU       r4         c15    f5
# 499992  PECCU_D15_5_227.png  pPECCU       r4         c15    f5
# 499993  PECCU_D15_5_228.png  pPECCU       r4         c15    f5
#
#                         prcfo cell_id  test test2 pathogen treatment  \
# 0         pPECCU_r2_c19_f1_o1      o1   NaN  None       nc   sample1
# 1         pPECCU_r2_c19_f1_o2      o2   NaN  None       nc   sample1
# 2         pPECCU_r2_c19_f1_o3      o3   NaN  None       nc   sample1
# 3         pPECCU_r2_c19_f1_o4      o4   NaN  None       nc   sample1
# 4         pPECCU_r2_c19_f1_o5      o5   NaN  None       nc   sample1
# ...                       ...     ...   ...   ...      ...       ...
# 499989  pPECCU_r4_c15_f5_o224    o224   NaN  None      NaN   sample2
# 499990  pPECCU_r4_c15_f5_o225    o225   NaN  None      NaN   sample2
# 499991  pPECCU_r4_c15_f5_o226    o226   NaN  None      NaN   sample2
# 499992  pPECCU_r4_c15_f5_o227    o227   NaN  None      NaN   sample2
# 499993  pPECCU_r4_c15_f5_o228    o228   NaN  None      NaN   sample2
#
#          condition
# 0       nc_sample1
# 1       nc_sample1
# 2       nc_sample1
# 3       nc_sample1
# 4       nc_sample1
# ...            ...
# 499989     sample2
# 499990     sample2
# 499991     sample2
# 499992     sample2
# 499993     sample2
#
# [196734 rows x 13 columns]
# Class sizes: [5995, 6513]
# Using the smallest class size: 5995
# Found 5995 images for class nc_sample1
# Found 6513 images for class pc_sample1
# class_path_list 2
# data 5995 0.1
# Progress: 0/11990, operation_type: Copying files for Train dataset, None
# Progress: 1/11990, operation_type: Copying files for Train dataset, None
# Progress: 2/11990, operation_type: Copying files for Train dataset, None
# Progress: 3/11990, operation_type: Copying files for Train dataset, None
# Progress: 4/11990, operation_type: Copying files for Train dataset, None
# Progress: 5/11990, operation_type: Copying files for Train dataset, None
# Progress: 6/11990, operation_type: Copying files for Train dataset, None
# Progress: 7/11990, operation_type: Copying files for Train dataset, None
# Progress: 8/11990, operation_type: Copying files for Train dataset, None
# Progress: 9/11990, operation_type: Copying files for Train dataset, None
# Progress: 10/11990, operation_type: Copying files for Train dataset, None
# Progress: 11/11990, operation_type: Copying files for Train dataset, None
# Progress: 12/11990, operation_type: Copying files for Train dataset, None
# Progress: 13/11990, operation_type: Copying files for Train dataset, None
# Progress: 14/11990, operation_type: Copying files for Train dataset, None
# Progress: 15/11990, operation_type: Copying files for Train dataset, None
# Progress: 16/11990, operation_type: Copying files for Train dataset, None
# Progress: 17/11990, operation_type: Copying files for Train dataset, None
# Progress: 18/11990, operation_type: Copying files for Train dataset, None
# Progress: 19/11990, operation_type: Copying files for Train dataset, None
# Progress: 20/11990, operation_type: Copying files for Train dataset, None
# Progress: 21/11990, operation_type: Copying files for Train dataset, None
# Progress: 22/11990, operation_type: Copying files for Train dataset, None
# Progress: 23/11990, operation_type: Copying files for Train dataset, None
# Progress: 24/11990, operation_type: Copying files for Train dataset, None
# Progress: 25/11990, operation_type: Copying files for Train dataset, None
# Progress: 26/11990, operation_type: Copying files for Train dataset, None
# Progress: 27/11990, operation_type: Copying files for Train dataset, None
# Progress: 28/11990, operation_type: Copying files for Train dataset, None
# Progress: 29/11990, operation_type: Copying files for Train dataset, None
# Progress: 30/11990, operation_type: Copying files for Train dataset, None
# Progress: 31/11990, operation_type: Copying files for Train dataset, None
# Progress: 32/11990, operation_type: Copying files for Train dataset, None
# Progress: 33/11990, operation_type: Copying files for Train dataset, None
# Progress: 34/11990, operation_type: Copying files for Train dataset, None
# Progress: 35/11990, operation_type: Copying files for Train dataset, None
# Progress: 36/11990, operation_type: Copying files for Train dataset, None
# Progress: 37/11990, operation_type: Copying files for Train dataset, None
# Progress: 38/11990, operation_type: Copying files for Train dataset, None
# Progress: 39/11990, operation_type: Copying files for Train dataset, None
# Progress: 40/11990, operation_type: Copying files for Train dataset, None
# Progress: 41/11990, operation_type: Copying files for Train dataset, None
# Progress: 42/11990, operation_type: Copying files for Train dataset, None
# Progress: 43/11990, operation_type: Copying files for Train dataset, None
# Progress: 44/11990, operation_type: Copying files for Train dataset, None
# Progress: 45/11990, operation_type: Copying files for Train dataset, None
# Progress: 46/11990, operation_type: Copying files for Train dataset, None
# Progress: 47/11990, operation_type: Copying files for Train dataset, None
# Progress: 48/11990, operation_type: Copying files for Train dataset, None
# Progress: 49/11990, operation_type: Copying files for Train dataset, None
# Progress: 50/11990, operation_type: Copying files for Train dataset, None
# Progress: 51/11990, operation_type: Copying files for Train dataset, None
# Progress: 52/11990, operation_type: Copying files for Train dataset, None
# Progress: 53/11990, operation_type: Copying files for Train dataset, None
# Progress: 54/11990, operation_type: Copying files for Train dataset, None
# Progress: 55/11990, operation_type: Copying files for Train dataset, None
# Progress: 56/11990, operation_type: Copying files for Train dataset, None
# Progress: 57/11990, operation_type: Copying files for Train dataset, None
# Progress: 58/11990, operation_type: Copying files for Train dataset, None
# Progress: 59/11990, operation_type: Copying files for Train dataset, None
# Progress: 60/11990, operation_type: Copying files for Train dataset, None
# Progress: 61/11990, operation_type: Copying files for Train dataset, None
# Progress: 62/11990, operation_type: Copying files for Train dataset, None
# Progress: 63/11990, operation_type: Copying files for Train dataset, None
# Progress: 64/11990, operation_type: Copying files for Train dataset, None
# Progress: 65/11990, operation_type: Copying files for Train dataset, None
# Progress: 66/11990, operation_type: Copying files for Train dataset, None
# Progress: 67/11990, operation_type: Copying files for Train dataset, None
# Progress: 68/11990, operation_type: Copying files for Train dataset, None
# Progress: 69/11990, operation_type: Copying files for Train dataset, None
# Progress: 70/11990, operation_type: Copying files for Train dataset, None
# Progress: 71/11990, operation_type: Copying files for Train dataset, None
# Progress: 72/11990, operation_type: Copying files for Train dataset, None
# Progress: 73/11990, operation_type: Copying files for Train dataset, None
# Progress: 74/11990, operation_type: Copying files for Train dataset, None
# Progress: 75/11990, operation_type: Copying files for Train dataset, None
# Progress: 76/11990, operation_type: Copying files for Train dataset, None
# Progress: 77/11990, operation_type: Copying files for Train dataset, None
# Progress: 78/11990, operation_type: Copying files for Train dataset, None
# Progress: 79/11990, operation_type: Copying files for Train dataset, None
# Progress: 80/11990, operation_type: Copying files for Train dataset, None
# Progress: 81/11990, operation_type: Copying files for Train dataset, None
# Progress: 82/11990, operation_type: Copying files for Train dataset, None
# Progress: 83/11990, operation_type: Copying files for Train dataset, None
# Progress: 84/11990, operation_type: Copying files for Train dataset, None
# Progress: 85/11990, operation_type: Copying files for Train dataset, None
# Progress: 86/11990, operation_type: Copying files for Train dataset, None
# Progress: 87/11990, operation_type: Copying files for Train dataset, None
# Progress: 88/11990, operation_type: Copying files for Train dataset, None
# Progress: 89/11990, operation_type: Copying files for Train dataset, None
# Progress: 90/11990, operation_type: Copying files for Train dataset, None
# Progress: 91/11990, operation_type: Copying files for Train dataset, None
# Progress: 92/11990, operation_type: Copying files for Train dataset, None
# Progress: 93/11990, operation_type: Copying files for Train dataset, None
# Progress: 94/11990, operation_type: Copying files for Train dataset, None
# Progress: 95/11990, operation_type: Copying files for Train dataset, None
# Progress: 96/11990, operation_type: Copying files for Train dataset, None
# Progress: 97/11990, operation_type: Copying files for Train dataset, None
# Progress: 98/11990, operation_type: Copying files for Train dataset, None
# Progress: 99/11990, operation_type: Copying files for Train dataset, None
# Progress: 100/11990, operation_type: Copying files for Train dataset, None
# Progress: 101/11990, operation_type: Copying files for Train dataset, None
# Progress: 102/11990, operation_type: Copying files for Train dataset, None
# Progress: 103/11990, operation_type: Copying files for Train dataset, None
# Progress: 104/11990, operation_type: Copying files for Train dataset, None
# Progress: 105/11990, operation_type: Copying files for Train dataset, None
# Progress: 106/11990, operation_type: Copying files for Train dataset, None
# Progress: 107/11990, operation_type: Copying files for Train dataset, None
# Progress: 108/11990, operation_type: Copying files for Train dataset, None
# Progress: 109/11990, operation_type: Copying files for Train dataset, None
# Progress: 110/11990, operation_type: Copying files for Train dataset, None
# Progress: 111/11990, operation_type: Copying files for Train dataset, None
# Progress: 112/11990, operation_type: Copying files for Train dataset, None
# Progress: 113/11990, operation_type: Copying files for Train dataset, None
# Progress: 114/11990, operation_type: Copying files for Train dataset, None
# Progress: 115/11990, operation_type: Copying files for Train dataset, None
# Progress: 116/11990, operation_type: Copying files for Train dataset, None
# Progress: 117/11990, operation_type: Copying files for Train dataset, None
# Progress: 118/11990, operation_type: Copying files for Train dataset, None
# Progress: 119/11990, operation_type: Copying files for Train dataset, None
# Progress: 120/11990, operation_type: Copying files for Train dataset, None
# Progress: 121/11990, operation_type: Copying files for Train dataset, None
# Progress: 122/11990, operation_type: Copying files for Train dataset, None
# Progress: 123/11990, operation_type: Copying files for Train dataset, None
# Progress: 124/11990, operation_type: Copying files for Train dataset, None
# Progress: 125/11990, operation_type: Copying files for Train dataset, None
# Progress: 126/11990, operation_type: Copying files for Train dataset, None
# Progress: 127/11990, operation_type: Copying files for Train dataset, None
# Progress: 128/11990, operation_type: Copying files for Train dataset, None
# Progress: 129/11990, operation_type: Copying files for Train dataset, None
# Progress: 130/11990, operation_type: Copying files for Train dataset, None
# Progress: 131/11990, operation_type: Copying files for Train dataset, None
# Progress: 132/11990, operation_type: Copying files for Train dataset, None
# Progress: 133/11990, operation_type: Copying files for Train dataset, None
# Progress: 134/11990, operation_type: Copying files for Train dataset, None
# Progress: 135/11990, operation_type: Copying files for Train dataset, None
# Progress: 136/11990, operation_type: Copying files for Train dataset, None
# Progress: 137/11990, operation_type: Copying files for Train dataset, None
# Progress: 138/11990, operation_type: Copying files for Train dataset, None
# Progress: 139/11990, operation_type: Copying files for Train dataset, None
# Progress: 140/11990, operation_type: Copying files for Train dataset, None
# Progress: 141/11990, operation_type: Copying files for Train dataset, None
# Progress: 142/11990, operation_type: Copying files for Train dataset, None
# Progress: 143/11990, operation_type: Copying files for Train dataset, None
# Progress: 144/11990, operation_type: Copying files for Train dataset, None
# Progress: 145/11990, operation_type: Copying files for Train dataset, None
# Progress: 146/11990, operation_type: Copying files for Train dataset, None
# Progress: 147/11990, operation_type: Copying files for Train dataset, None
# Progress: 148/11990, operation_type: Copying files for Train dataset, None
# Progress: 149/11990, operation_type: Copying files for Train dataset, None
# Progress: 150/11990, operation_type: Copying files for Train dataset, None
# Progress: 151/11990, operation_type: Copying files for Train dataset, None
# Progress: 152/11990, operation_type: Copying files for Train dataset, None
# Progress: 153/11990, operation_type: Copying files for Train dataset, None
# Progress: 154/11990, operation_type: Copying files for Train dataset, None
# Progress: 155/11990, operation_type: Copying files for Train dataset, None
# Progress: 156/11990, operation_type: Copying files for Train dataset, None
# Progress: 157/11990, operation_type: Copying files for Train dataset, None
# Progress: 158/11990, operation_type: Copying files for Train dataset, None
# Progress: 159/11990, operation_type: Copying files for Train dataset, None
# Progress: 160/11990, operation_type: Copying files for Train dataset, None
# Progress: 161/11990, operation_type: Copying files for Train dataset, None
# Progress: 162/11990, operation_type: Copying files for Train dataset, None
# Progress: 163/11990, operation_type: Copying files for Train dataset, None
# Progress: 164/11990, operation_type: Copying files for Train dataset, None
# Progress: 165/11990, operation_type: Copying files for Train dataset, None
# Progress: 166/11990, operation_type: Copying files for Train dataset, None
# Progress: 167/11990, operation_type: Copying files for Train dataset, None
# Progress: 168/11990, operation_type: Copying files for Train dataset, None
# Progress: 169/11990, operation_type: Copying files for Train dataset, None
# Progress: 170/11990, operation_type: Copying files for Train dataset, None
# Progress: 171/11990, operation_type: Copying files for Train dataset, None
# Progress: 172/11990, operation_type: Copying files for Train dataset, None
# Progress: 173/11990, operation_type: Copying files for Train dataset, None
# Progress: 174/11990, operation_type: Copying files for Train dataset, None
# Progress: 175/11990, operation_type: Copying files for Train dataset, None
# Progress: 176/11990, operation_type: Copying files for Train dataset, None
# Progress: 177/11990, operation_type: Copying files for Train dataset, None
# Progress: 178/11990, operation_type: Copying files for Train dataset, None
# Progress: 179/11990, operation_type: Copying files for Train dataset, None
# Progress: 180/11990, operation_type: Copying files for Train dataset, None
# Progress: 181/11990, operation_type: Copying files for Train dataset, None
# Progress: 182/11990, operation_type: Copying files for Train dataset, None
# Progress: 183/11990, operation_type: Copying files for Train dataset, None
# Progress: 184/11990, operation_type: Copying files for Train dataset, None
# Progress: 185/11990, operation_type: Copying files for Train dataset, None
# Progress: 186/11990, operation_type: Copying files for Train dataset, None
# Progress: 187/11990, operation_type: Copying files for Train dataset, None
# Progress: 188/11990, operation_type: Copying files for Train dataset, None
# Progress: 189/11990, operation_type: Copying files for Train dataset, None
# Progress: 190/11990, operation_type: Copying files for Train dataset, None
# Progress: 191/11990, operation_type: Copying files for Train dataset, None
# Progress: 192/11990, operation_type: Copying files for Train dataset, None
# Progress: 193/11990, operation_type: Copying files for Train dataset, None
# Progress: 194/11990, operation_type: Copying files for Train dataset, None
# Progress: 195/11990, operation_type: Copying files for Train dataset, None
# Progress: 196/11990, operation_type: Copying files for Train dataset, None
# Progress: 197/11990, operation_type: Copying files for Train dataset, None
# Progress: 198/11990, operation_type: Copying files for Train dataset, None
# Progress: 199/11990, operation_type: Copying files for Train dataset, None
# Progress: 200/11990, operation_type: Copying files for Train dataset, None
# Progress: 201/11990, operation_type: Copying files for Train dataset, None
# Progress: 202/11990, operation_type: Copying files for Train dataset, None
# Progress: 203/11990, operation_type: Copying files for Train dataset, None
# Progress: 204/11990, operation_type: Copying files for Train dataset, None
# Progress: 205/11990, operation_type: Copying files for Train dataset, None
# Progress: 206/11990, operation_type: Copying files for Train dataset, None
# Progress: 207/11990, operation_type: Copying files for Train dataset, None
# Progress: 208/11990, operation_type: Copying files for Train dataset, None
# Progress: 209/11990, operation_type: Copying files for Train dataset, None
# Progress: 210/11990, operation_type: Copying files for Train dataset, None
# Progress: 211/11990, operation_type: Copying files for Train dataset, None
# Progress: 212/11990, operation_type: Copying files for Train dataset, None
# Progress: 213/11990, operation_type: Copying files for Train dataset, None
# Progress: 214/11990, operation_type: Copying files for Train dataset, None
# Progress: 215/11990, operation_type: Copying files for Train dataset, None
# Progress: 216/11990, operation_type: Copying files for Train dataset, None
# Progress: 217/11990, operation_type: Copying files for Train dataset, None
# Progress: 218/11990, operation_type: Copying files for Train dataset, None
# Progress: 219/11990, operation_type: Copying files for Train dataset, None
# Progress: 220/11990, operation_type: Copying files for Train dataset, None
# Progress: 221/11990, operation_type: Copying files for Train dataset, None
# Progress: 222/11990, operation_type: Copying files for Train dataset, None
# Progress: 223/11990, operation_type: Copying files for Train dataset, None
# Progress: 224/11990, operation_type: Copying files for Train dataset, None
# Progress: 225/11990, operation_type: Copying files for Train dataset, None
# Progress: 226/11990, operation_type: Copying files for Train dataset, None
# Progress: 227/11990, operation_type: Copying files for Train dataset, None
# Progress: 228/11990, operation_type: Copying files for Train dataset, None
# Progress: 229/11990, operation_type: Copying files for Train dataset, None
# Progress: 230/11990, operation_type: Copying files for Train dataset, None
# Progress: 231/11990, operation_type: Copying files for Train dataset, None
# Progress: 232/11990, operation_type: Copying files for Train dataset, None
# Progress: 233/11990, operation_type: Copying files for Train dataset, None
# Progress: 234/11990, operation_type: Copying files for Train dataset, None
# Progress: 235/11990, operation_type: Copying files for Train dataset, None
# Progress: 236/11990, operation_type: Copying files for Train dataset, None
# Progress: 237/11990, operation_type: Copying files for Train dataset, None
# Progress: 238/11990, operation_type: Copying files for Train dataset, None
# Progress: 239/11990, operation_type: Copying files for Train dataset, None
# Progress: 240/11990, operation_type: Copying files for Train dataset, None
# Progress: 241/11990, operation_type: Copying files for Train dataset, None
# Progress: 242/11990, operation_type: Copying files for Train dataset, None
# Progress: 243/11990, operation_type: Copying files for Train dataset, None
# Progress: 244/11990, operation_type: Copying files for Train dataset, None
# Progress: 245/11990, operation_type: Copying files for Train dataset, None
# Progress: 246/11990, operation_type: Copying files for Train dataset, None
# Progress: 247/11990, operation_type: Copying files for Train dataset, None
# Progress: 248/11990, operation_type: Copying files for Train dataset, None
# Progress: 249/11990, operation_type: Copying files for Train dataset, None
# Progress: 250/11990, operation_type: Copying files for Train dataset, None
# Progress: 251/11990, operation_type: Copying files for Train dataset, None
# Progress: 252/11990, operation_type: Copying files for Train dataset, None
# Progress: 253/11990, operation_type: Copying files for Train dataset, None
# Progress: 254/11990, operation_type: Copying files for Train dataset, None
# Progress: 255/11990, operation_type: Copying files for Train dataset, None
# Progress: 256/11990, operation_type: Copying files for Train dataset, None
# Progress: 257/11990, operation_type: Copying files for Train dataset, None
# Progress: 258/11990, operation_type: Copying files for Train dataset, None
# Progress: 259/11990, operation_type: Copying files for Train dataset, None
# Progress: 260/11990, operation_type: Copying files for Train dataset, None
# Progress: 261/11990, operation_type: Copying files for Train dataset, None
# Progress: 262/11990, operation_type: Copying files for Train dataset, None
# Progress: 263/11990, operation_type: Copying files for Train dataset, None
# Progress: 264/11990, operation_type: Copying files for Train dataset, None
# Progress: 265/11990, operation_type: Copying files for Train dataset, None
# Progress: 266/11990, operation_type: Copying files for Train dataset, None
# Progress: 267/11990, operation_type: Copying files for Train dataset, None
# Progress: 268/11990, operation_type: Copying files for Train dataset, None
# Progress: 269/11990, operation_type: Copying files for Train dataset, None
# Progress: 270/11990, operation_type: Copying files for Train dataset, None
# Progress: 271/11990, operation_type: Copying files for Train dataset, None
# Progress: 272/11990, operation_type: Copying files for Train dataset, None
# Progress: 273/11990, operation_type: Copying files for Train dataset, None
# Progress: 274/11990, operation_type: Copying files for Train dataset, None
# Progress: 275/11990, operation_type: Copying files for Train dataset, None
# Progress: 276/11990, operation_type: Copying files for Train dataset, None
# Progress: 277/11990, operation_type: Copying files for Train dataset, None
# Progress: 278/11990, operation_type: Copying files for Train dataset, None
# Progress: 279/11990, operation_type: Copying files for Train dataset, None
# Progress: 280/11990, operation_type: Copying files for Train dataset, None
# Progress: 281/11990, operation_type: Copying files for Train dataset, None
# Progress: 282/11990, operation_type: Copying files for Train dataset, None
# Progress: 283/11990, operation_type: Copying files for Train dataset, None
# Progress: 284/11990, operation_type: Copying files for Train dataset, None
# Progress: 285/11990, operation_type: Copying files for Train dataset, None
# Progress: 286/11990, operation_type: Copying files for Train dataset, None
# Progress: 287/11990, operation_type: Copying files for Train dataset, None
# Progress: 288/11990, operation_type: Copying files for Train dataset, None
# Progress: 289/11990, operation_type: Copying files for Train dataset, None
# Progress: 290/11990, operation_type: Copying files for Train dataset, None
# Progress: 291/11990, operation_type: Copying files for Train dataset, None
# Progress: 292/11990, operation_type: Copying files for Train dataset, None
# Progress: 293/11990, operation_type: Copying files for Train dataset, None
# Progress: 294/11990, operation_type: Copying files for Train dataset, None
# Progress: 295/11990, operation_type: Copying files for Train dataset, None
# Progress: 296/11990, operation_type: Copying files for Train dataset, None
# Progress: 297/11990, operation_type: Copying files for Train dataset, None
# Progress: 298/11990, operation_type: Copying files for Train dataset, None
# Progress: 299/11990, operation_type: Copying files for Train dataset, None
# Progress: 300/11990, operation_type: Copying files for Train dataset, None
# Progress: 301/11990, operation_type: Copying files for Train dataset, None
# Progress: 302/11990, operation_type: Copying files for Train dataset, None
# Progress: 303/11990, operation_type: Copying files for Train dataset, None
# Progress: 304/11990, operation_type: Copying files for Train dataset, None
# Progress: 305/11990, operation_type: Copying files for Train dataset, None
# Progress: 306/11990, operation_type: Copying files for Train dataset, None
# Progress: 307/11990, operation_type: Copying files for Train dataset, None
# Progress: 308/11990, operation_type: Copying files for Train dataset, None
# Progress: 309/11990, operation_type: Copying files for Train dataset, None
# Progress: 310/11990, operation_type: Copying files for Train dataset, None
# Progress: 311/11990, operation_type: Copying files for Train dataset, None
# Progress: 312/11990, operation_type: Copying files for Train dataset, None
# Progress: 313/11990, operation_type: Copying files for Train dataset, None
# Progress: 314/11990, operation_type: Copying files for Train dataset, None
# Progress: 315/11990, operation_type: Copying files for Train dataset, None
# Progress: 316/11990, operation_type: Copying files for Train dataset, None
# Progress: 317/11990, operation_type: Copying files for Train dataset, None
# Progress: 318/11990, operation_type: Copying files for Train dataset, None
# Progress: 319/11990, operation_type: Copying files for Train dataset, None
# Progress: 320/11990, operation_type: Copying files for Train dataset, None
# Progress: 321/11990, operation_type: Copying files for Train dataset, None
# Progress: 322/11990, operation_type: Copying files for Train dataset, None
# Progress: 323/11990, operation_type: Copying files for Train dataset, None
# Progress: 324/11990, operation_type: Copying files for Train dataset, None
# Progress: 325/11990, operation_type: Copying files for Train dataset, None
# Progress: 326/11990, operation_type: Copying files for Train dataset, None
# Progress: 327/11990, operation_type: Copying files for Train dataset, None
# Progress: 328/11990, operation_type: Copying files for Train dataset, None
# Progress: 329/11990, operation_type: Copying files for Train dataset, None
# Progress: 330/11990, operation_type: Copying files for Train dataset, None
# Progress: 331/11990, operation_type: Copying files for Train dataset, None
# Progress: 332/11990, operation_type: Copying files for Train dataset, None
# Progress: 333/11990, operation_type: Copying files for Train dataset, None
# Progress: 334/11990, operation_type: Copying files for Train dataset, None
# Progress: 335/11990, operation_type: Copying files for Train dataset, None
# Progress: 336/11990, operation_type: Copying files for Train dataset, None
# Progress: 337/11990, operation_type: Copying files for Train dataset, None
# Progress: 338/11990, operation_type: Copying files for Train dataset, None
# Progress: 339/11990, operation_type: Copying files for Train dataset, None
# Progress: 340/11990, operation_type: Copying files for Train dataset, None
# Progress: 341/11990, operation_type: Copying files for Train dataset, None
# Progress: 342/11990, operation_type: Copying files for Train dataset, None
# Progress: 343/11990, operation_type: Copying files for Train dataset, None
# Progress: 344/11990, operation_type: Copying files for Train dataset, None
# Progress: 345/11990, operation_type: Copying files for Train dataset, None
# Progress: 346/11990, operation_type: Copying files for Train dataset, None
# Progress: 347/11990, operation_type: Copying files for Train dataset, None
# Progress: 348/11990, operation_type: Copying files for Train dataset, None
# Progress: 349/11990, operation_type: Copying files for Train dataset, None
# Progress: 350/11990, operation_type: Copying files for Train dataset, None
# Progress: 351/11990, operation_type: Copying files for Train dataset, None
# Progress: 352/11990, operation_type: Copying files for Train dataset, None
# Progress: 353/11990, operation_type: Copying files for Train dataset, None
# Progress: 354/11990, operation_type: Copying files for Train dataset, None
# Progress: 355/11990, operation_type: Copying files for Train dataset, None
# Progress: 356/11990, operation_type: Copying files for Train dataset, None
# Progress: 357/11990, operation_type: Copying files for Train dataset, None
# Progress: 358/11990, operation_type: Copying files for Train dataset, None
# Progress: 359/11990, operation_type: Copying files for Train dataset, None
# Progress: 360/11990, operation_type: Copying files for Train dataset, None
# Progress: 361/11990, operation_type: Copying files for Train dataset, None
# Progress: 362/11990, operation_type: Copying files for Train dataset, None
# Progress: 363/11990, operation_type: Copying files for Train dataset, None
# Progress: 364/11990, operation_type: Copying files for Train dataset, None
# Progress: 365/11990, operation_type: Copying files for Train dataset, None
# Progress: 366/11990, operation_type: Copying files for Train dataset, None
# Progress: 367/11990, operation_type: Copying files for Train dataset, None
# Progress: 368/11990, operation_type: Copying files for Train dataset, None
# Progress: 369/11990, operation_type: Copying files for Train dataset, None
# Progress: 370/11990, operation_type: Copying files for Train dataset, None
# Progress: 371/11990, operation_type: Copying files for Train dataset, None
# Progress: 372/11990, operation_type: Copying files for Train dataset, None
# Progress: 373/11990, operation_type: Copying files for Train dataset, None
# Progress: 374/11990, operation_type: Copying files for Train dataset, None
# Progress: 375/11990, operation_type: Copying files for Train dataset, None
# Progress: 376/11990, operation_type: Copying files for Train dataset, None
# Progress: 377/11990, operation_type: Copying files for Train dataset, None
# Progress: 378/11990, operation_type: Copying files for Train dataset, None
# Progress: 379/11990, operation_type: Copying files for Train dataset, None
# Progress: 380/11990, operation_type: Copying files for Train dataset, None
# Progress: 381/11990, operation_type: Copying files for Train dataset, None
# Progress: 382/11990, operation_type: Copying files for Train dataset, None
# Progress: 383/11990, operation_type: Copying files for Train dataset, None
# Progress: 384/11990, operation_type: Copying files for Train dataset, None
# Progress: 385/11990, operation_type: Copying files for Train dataset, None
# Progress: 386/11990, operation_type: Copying files for Train dataset, None
# Progress: 387/11990, operation_type: Copying files for Train dataset, None
# Progress: 388/11990, operation_type: Copying files for Train dataset, None
# Progress: 389/11990, operation_type: Copying files for Train dataset, None
# Progress: 390/11990, operation_type: Copying files for Train dataset, None
# Progress: 391/11990, operation_type: Copying files for Train dataset, None
# Progress: 392/11990, operation_type: Copying files for Train dataset, None
# Progress: 393/11990, operation_type: Copying files for Train dataset, None
# Progress: 394/11990, operation_type: Copying files for Train dataset, None
# Progress: 395/11990, operation_type: Copying files for Train dataset, None
# Progress: 396/11990, operation_type: Copying files for Train dataset, None
# Progress: 397/11990, operation_type: Copying files for Train dataset, None
# Progress: 398/11990, operation_type: Copying files for Train dataset, None
# Progress: 399/11990, operation_type: Copying files for Train dataset, None
# Progress: 400/11990, operation_type: Copying files for Train dataset, None
# Progress: 401/11990, operation_type: Copying files for Train dataset, None
# Progress: 402/11990, operation_type: Copying files for Train dataset, None
# Progress: 403/11990, operation_type: Copying files for Train dataset, None
# Progress: 404/11990, operation_type: Copying files for Train dataset, None
# Progress: 405/11990, operation_type: Copying files for Train dataset, None
# Progress: 406/11990, operation_type: Copying files for Train dataset, None
# Progress: 407/11990, operation_type: Copying files for Train dataset, None
# Progress: 408/11990, operation_type: Copying files for Train dataset, None
# Progress: 409/11990, operation_type: Copying files for Train dataset, None
# Progress: 410/11990, operation_type: Copying files for Train dataset, None
# Progress: 411/11990, operation_type: Copying files for Train dataset, None
# Progress: 412/11990, operation_type: Copying files for Train dataset, None
# Progress: 413/11990, operation_type: Copying files for Train dataset, None
# Progress: 414/11990, operation_type: Copying files for Train dataset, None
# Progress: 415/11990, operation_type: Copying files for Train dataset, None
# Progress: 416/11990, operation_type: Copying files for Train dataset, None
# Progress: 417/11990, operation_type: Copying files for Train dataset, None
# Progress: 418/11990, operation_type: Copying files for Train dataset, None
# Progress: 419/11990, operation_type: Copying files for Train dataset, None
# Progress: 420/11990, operation_type: Copying files for Train dataset, None
# Progress: 421/11990, operation_type: Copying files for Train dataset, None
# Progress: 422/11990, operation_type: Copying files for Train dataset, None
# Progress: 423/11990, operation_type: Copying files for Train dataset, None
# Progress: 424/11990, operation_type: Copying files for Train dataset, None
# Progress: 425/11990, operation_type: Copying files for Train dataset, None
# Progress: 426/11990, operation_type: Copying files for Train dataset, None
# Progress: 427/11990, operation_type: Copying files for Train dataset, None
# Progress: 428/11990, operation_type: Copying files for Train dataset, None
# Progress: 429/11990, operation_type: Copying files for Train dataset, None
# Progress: 430/11990, operation_type: Copying files for Train dataset, None
# Progress: 431/11990, operation_type: Copying files for Train dataset, None
# Progress: 432/11990, operation_type: Copying files for Train dataset, None
# Progress: 433/11990, operation_type: Copying files for Train dataset, None
# Progress: 434/11990, operation_type: Copying files for Train dataset, None
# Progress: 435/11990, operation_type: Copying files for Train dataset, None
# Progress: 436/11990, operation_type: Copying files for Train dataset, None
# Progress: 437/11990, operation_type: Copying files for Train dataset, None
# Progress: 438/11990, operation_type: Copying files for Train dataset, None
# Progress: 439/11990, operation_type: Copying files for Train dataset, None
# Progress: 440/11990, operation_type: Copying files for Train dataset, None
# Progress: 441/11990, operation_type: Copying files for Train dataset, None
# Progress: 442/11990, operation_type: Copying files for Train dataset, None
# Progress: 443/11990, operation_type: Copying files for Train dataset, None
# Progress: 444/11990, operation_type: Copying files for Train dataset, None
# Progress: 445/11990, operation_type: Copying files for Train dataset, None
# Progress: 446/11990, operation_type: Copying files for Train dataset, None
# Progress: 447/11990, operation_type: Copying files for Train dataset, None
# Progress: 448/11990, operation_type: Copying files for Train dataset, None
# Progress: 449/11990, operation_type: Copying files for Train dataset, None
# Progress: 450/11990, operation_type: Copying files for Train dataset, None
# Progress: 451/11990, operation_type: Copying files for Train dataset, None
# Progress: 452/11990, operation_type: Copying files for Train dataset, None
# Progress: 453/11990, operation_type: Copying files for Train dataset, None
# Progress: 454/11990, operation_type: Copying files for Train dataset, None
# Progress: 455/11990, operation_type: Copying files for Train dataset, None
# Progress: 456/11990, operation_type: Copying files for Train dataset, None
# Progress: 457/11990, operation_type: Copying files for Train dataset, None
# Progress: 458/11990, operation_type: Copying files for Train dataset, None
# Progress: 459/11990, operation_type: Copying files for Train dataset, None
# Progress: 460/11990, operation_type: Copying files for Train dataset, None
# Progress: 461/11990, operation_type: Copying files for Train dataset, None
# Progress: 462/11990, operation_type: Copying files for Train dataset, None
# Progress: 463/11990, operation_type: Copying files for Train dataset, None
# Progress: 464/11990, operation_type: Copying files for Train dataset, None
# Progress: 465/11990, operation_type: Copying files for Train dataset, None
# Progress: 466/11990, operation_type: Copying files for Train dataset, None
# Progress: 467/11990, operation_type: Copying files for Train dataset, None
# Progress: 468/11990, operation_type: Copying files for Train dataset, None
# Progress: 469/11990, operation_type: Copying files for Train dataset, None
# Progress: 470/11990, operation_type: Copying files for Train dataset, None
# Progress: 471/11990, operation_type: Copying files for Train dataset, None
# Progress: 472/11990, operation_type: Copying files for Train dataset, None
# Progress: 473/11990, operation_type: Copying files for Train dataset, None
# Progress: 474/11990, operation_type: Copying files for Train dataset, None
# Progress: 475/11990, operation_type: Copying files for Train dataset, None
# Progress: 476/11990, operation_type: Copying files for Train dataset, None
# Progress: 477/11990, operation_type: Copying files for Train dataset, None
# Progress: 478/11990, operation_type: Copying files for Train dataset, None
# Progress: 479/11990, operation_type: Copying files for Train dataset, None
# Progress: 480/11990, operation_type: Copying files for Train dataset, None
# Progress: 481/11990, operation_type: Copying files for Train dataset, None
# Progress: 482/11990, operation_type: Copying files for Train dataset, None
# Progress: 483/11990, operation_type: Copying files for Train dataset, None
# Progress: 484/11990, operation_type: Copying files for Train dataset, None
# Progress: 485/11990, operation_type: Copying files for Train dataset, None
# Progress: 486/11990, operation_type: Copying files for Train dataset, None
# Progress: 487/11990, operation_type: Copying files for Train dataset, None
# Progress: 488/11990, operation_type: Copying files for Train dataset, None
# Progress: 489/11990, operation_type: Copying files for Train dataset, None
# Progress: 490/11990, operation_type: Copying files for Train dataset, None
# Progress: 491/11990, operation_type: Copying files for Train dataset, None
# Progress: 492/11990, operation_type: Copying files for Train dataset, None
# Progress: 493/11990, operation_type: Copying files for Train dataset, None
# Progress: 494/11990, operation_type: Copying files for Train dataset, None
# Progress: 495/11990, operation_type: Copying files for Train dataset, None
# Progress: 496/11990, operation_type: Copying files for Train dataset, None
# Progress: 497/11990, operation_type: Copying files for Train dataset, None
# Progress: 498/11990, operation_type: Copying files for Train dataset, None
# Progress: 499/11990, operation_type: Copying files for Train dataset, None
# Progress: 500/11990, operation_type: Copying files for Train dataset, None
# Progress: 501/11990, operation_type: Copying files for Train dataset, None
# Progress: 502/11990, operation_type: Copying files for Train dataset, None
# Progress: 503/11990, operation_type: Copying files for Train dataset, None
# Progress: 504/11990, operation_type: Copying files for Train dataset, None
# Progress: 505/11990, operation_type: Copying files for Train dataset, None
# Progress: 506/11990, operation_type: Copying files for Train dataset, None
# Progress: 507/11990, operation_type: Copying files for Train dataset, None
# Progress: 508/11990, operation_type: Copying files for Train dataset, None
# Progress: 509/11990, operation_type: Copying files for Train dataset, None
# Progress: 510/11990, operation_type: Copying files for Train dataset, None
# Progress: 511/11990, operation_type: Copying files for Train dataset, None
# Progress: 512/11990, operation_type: Copying files for Train dataset, None
# Progress: 513/11990, operation_type: Copying files for Train dataset, None
# Progress: 514/11990, operation_type: Copying files for Train dataset, None
# Progress: 515/11990, operation_type: Copying files for Train dataset, None
# Progress: 516/11990, operation_type: Copying files for Train dataset, None
# Progress: 517/11990, operation_type: Copying files for Train dataset, None
# Progress: 518/11990, operation_type: Copying files for Train dataset, None
# Progress: 519/11990, operation_type: Copying files for Train dataset, None
# Progress: 520/11990, operation_type: Copying files for Train dataset, None
# Progress: 521/11990, operation_type: Copying files for Train dataset, None
# Progress: 522/11990, operation_type: Copying files for Train dataset, None
# Progress: 523/11990, operation_type: Copying files for Train dataset, None
# Progress: 524/11990, operation_type: Copying files for Train dataset, None
# Progress: 525/11990, operation_type: Copying files for Train dataset, None
# Progress: 526/11990, operation_type: Copying files for Train dataset, None
# Progress: 527/11990, operation_type: Copying files for Train dataset, None
# Progress: 528/11990, operation_type: Copying files for Train dataset, None
# Progress: 529/11990, operation_type: Copying files for Train dataset, None
# Progress: 530/11990, operation_type: Copying files for Train dataset, None
# Progress: 531/11990, operation_type: Copying files for Train dataset, None
# Progress: 532/11990, operation_type: Copying files for Train dataset, None
# Progress: 533/11990, operation_type: Copying files for Train dataset, None
# Progress: 534/11990, operation_type: Copying files for Train dataset, None
# Progress: 535/11990, operation_type: Copying files for Train dataset, None
# Progress: 536/11990, operation_type: Copying files for Train dataset, None
# Progress: 537/11990, operation_type: Copying files for Train dataset, None
# Progress: 538/11990, operation_type: Copying files for Train dataset, None
# Progress: 539/11990, operation_type: Copying files for Train dataset, None
# Progress: 540/11990, operation_type: Copying files for Train dataset, None
# Progress: 541/11990, operation_type: Copying files for Train dataset, None
# Progress: 542/11990, operation_type: Copying files for Train dataset, None
# Progress: 543/11990, operation_type: Copying files for Train dataset, None
# Progress: 544/11990, operation_type: Copying files for Train dataset, None
# Progress: 545/11990, operation_type: Copying files for Train dataset, None
# Progress: 546/11990, operation_type: Copying files for Train dataset, None
# Progress: 547/11990, operation_type: Copying files for Train dataset, None
# Progress: 548/11990, operation_type: Copying files for Train dataset, None
# Progress: 549/11990, operation_type: Copying files for Train dataset, None
# Progress: 550/11990, operation_type: Copying files for Train dataset, None
# Progress: 551/11990, operation_type: Copying files for Train dataset, None
# Progress: 552/11990, operation_type: Copying files for Train dataset, None
# Progress: 553/11990, operation_type: Copying files for Train dataset, None
# Progress: 554/11990, operation_type: Copying files for Train dataset, None
# Progress: 555/11990, operation_type: Copying files for Train dataset, None
# Progress: 556/11990, operation_type: Copying files for Train dataset, None
# Progress: 557/11990, operation_type: Copying files for Train dataset, None
# Progress: 558/11990, operation_type: Copying files for Train dataset, None
# Progress: 559/11990, operation_type: Copying files for Train dataset, None
# Progress: 560/11990, operation_type: Copying files for Train dataset, None
# Progress: 561/11990, operation_type: Copying files for Train dataset, None
# Progress: 562/11990, operation_type: Copying files for Train dataset, None
# Progress: 563/11990, operation_type: Copying files for Train dataset, None
# Progress: 564/11990, operation_type: Copying files for Train dataset, None
# Progress: 565/11990, operation_type: Copying files for Train dataset, None
# Progress: 566/11990, operation_type: Copying files for Train dataset, None
# Progress: 567/11990, operation_type: Copying files for Train dataset, None
# Progress: 568/11990, operation_type: Copying files for Train dataset, None
# Progress: 569/11990, operation_type: Copying files for Train dataset, None
# Progress: 570/11990, operation_type: Copying files for Train dataset, None
# Progress: 571/11990, operation_type: Copying files for Train dataset, None
# Progress: 572/11990, operation_type: Copying files for Train dataset, None
# Progress: 573/11990, operation_type: Copying files for Train dataset, None
# Progress: 574/11990, operation_type: Copying files for Train dataset, None
# Progress: 575/11990, operation_type: Copying files for Train dataset, None
# Progress: 576/11990, operation_type: Copying files for Train dataset, None
# Progress: 577/11990, operation_type: Copying files for Train dataset, None
# Progress: 578/11990, operation_type: Copying files for Train dataset, None
# Progress: 579/11990, operation_type: Copying files for Train dataset, None
# Progress: 580/11990, operation_type: Copying files for Train dataset, None
# ...
# Progress: 11784/11990, operation_type: Copying files for Test dataset, None
# Progress: 11785/11990, operation_type: Copying files for Test dataset, None
# Progress: 11786/11990, operation_type: Copying files for Test dataset, None
# Progress: 11787/11990, operation_type: Copying files for Test dataset, None
# Progress: 11788/11990, operation_type: Copying files for Test dataset, None
# Progress: 11789/11990, operation_type: Copying files for Test dataset, None
# Progress: 11790/11990, operation_type: Copying files for Test dataset, None
# Progress: 11791/11990, operation_type: Copying files for Test dataset, None
# Progress: 11792/11990, operation_type: Copying files for Test dataset, None
# Progress: 11793/11990, operation_type: Copying files for Test dataset, None
# Progress: 11794/11990, operation_type: Copying files for Test dataset, None
# Progress: 11795/11990, operation_type: Copying files for Test dataset, None
# Progress: 11796/11990, operation_type: Copying files for Test dataset, None
# Progress: 11797/11990, operation_type: Copying files for Test dataset, None
# Progress: 11798/11990, operation_type: Copying files for Test dataset, None
# Progress: 11799/11990, operation_type: Copying files for Test dataset, None
# Progress: 11800/11990, operation_type: Copying files for Test dataset, None
# Progress: 11801/11990, operation_type: Copying files for Test dataset, None
# Progress: 11802/11990, operation_type: Copying files for Test dataset, None
# Progress: 11803/11990, operation_type: Copying files for Test dataset, None
# Progress: 11804/11990, operation_type: Copying files for Test dataset, None
# Progress: 11805/11990, operation_type: Copying files for Test dataset, None
# Progress: 11806/11990, operation_type: Copying files for Test dataset, None
# Progress: 11807/11990, operation_type: Copying files for Test dataset, None
# Progress: 11808/11990, operation_type: Copying files for Test dataset, None
# Progress: 11809/11990, operation_type: Copying files for Test dataset, None
# Progress: 11810/11990, operation_type: Copying files for Test dataset, None
# Progress: 11811/11990, operation_type: Copying files for Test dataset, None
# Progress: 11812/11990, operation_type: Copying files for Test dataset, None
# Progress: 11813/11990, operation_type: Copying files for Test dataset, None
# Progress: 11814/11990, operation_type: Copying files for Test dataset, None
# Progress: 11815/11990, operation_type: Copying files for Test dataset, None
# Progress: 11816/11990, operation_type: Copying files for Test dataset, None
# Progress: 11817/11990, operation_type: Copying files for Test dataset, None
# Progress: 11818/11990, operation_type: Copying files for Test dataset, None
# Progress: 11819/11990, operation_type: Copying files for Test dataset, None
# Progress: 11820/11990, operation_type: Copying files for Test dataset, None
# Progress: 11821/11990, operation_type: Copying files for Test dataset, None
# Progress: 11822/11990, operation_type: Copying files for Test dataset, None
# Progress: 11823/11990, operation_type: Copying files for Test dataset, None
# Progress: 11824/11990, operation_type: Copying files for Test dataset, None
# Progress: 11825/11990, operation_type: Copying files for Test dataset, None
# Progress: 11826/11990, operation_type: Copying files for Test dataset, None
# Progress: 11827/11990, operation_type: Copying files for Test dataset, None
# Progress: 11828/11990, operation_type: Copying files for Test dataset, None
# Progress: 11829/11990, operation_type: Copying files for Test dataset, None
# Progress: 11830/11990, operation_type: Copying files for Test dataset, None
# Progress: 11831/11990, operation_type: Copying files for Test dataset, None
# Progress: 11832/11990, operation_type: Copying files for Test dataset, None
# Progress: 11833/11990, operation_type: Copying files for Test dataset, None
# Progress: 11834/11990, operation_type: Copying files for Test dataset, None
# Progress: 11835/11990, operation_type: Copying files for Test dataset, None
# Progress: 11836/11990, operation_type: Copying files for Test dataset, None
# Progress: 11837/11990, operation_type: Copying files for Test dataset, None
# Progress: 11838/11990, operation_type: Copying files for Test dataset, None
# Progress: 11839/11990, operation_type: Copying files for Test dataset, None
# Progress: 11840/11990, operation_type: Copying files for Test dataset, None
# Progress: 11841/11990, operation_type: Copying files for Test dataset, None
# Progress: 11842/11990, operation_type: Copying files for Test dataset, None
# Progress: 11843/11990, operation_type: Copying files for Test dataset, None
# Progress: 11844/11990, operation_type: Copying files for Test dataset, None
# Progress: 11845/11990, operation_type: Copying files for Test dataset, None
# Progress: 11846/11990, operation_type: Copying files for Test dataset, None
# Progress: 11847/11990, operation_type: Copying files for Test dataset, None
# Progress: 11848/11990, operation_type: Copying files for Test dataset, None
# Progress: 11849/11990, operation_type: Copying files for Test dataset, None
# Progress: 11850/11990, operation_type: Copying files for Test dataset, None
# Progress: 11851/11990, operation_type: Copying files for Test dataset, None
# Progress: 11852/11990, operation_type: Copying files for Test dataset, None
# Progress: 11853/11990, operation_type: Copying files for Test dataset, None
# Progress: 11854/11990, operation_type: Copying files for Test dataset, None
# Progress: 11855/11990, operation_type: Copying files for Test dataset, None
# Progress: 11856/11990, operation_type: Copying files for Test dataset, None
# Progress: 11857/11990, operation_type: Copying files for Test dataset, None
# Progress: 11858/11990, operation_type: Copying files for Test dataset, None
# Progress: 11859/11990, operation_type: Copying files for Test dataset, None
# Progress: 11860/11990, operation_type: Copying files for Test dataset, None
# Progress: 11861/11990, operation_type: Copying files for Test dataset, None
# Progress: 11862/11990, operation_type: Copying files for Test dataset, None
# Progress: 11863/11990, operation_type: Copying files for Test dataset, None
# Progress: 11864/11990, operation_type: Copying files for Test dataset, None
# Progress: 11865/11990, operation_type: Copying files for Test dataset, None
# Progress: 11866/11990, operation_type: Copying files for Test dataset, None
# Progress: 11867/11990, operation_type: Copying files for Test dataset, None
# Progress: 11868/11990, operation_type: Copying files for Test dataset, None
# Progress: 11869/11990, operation_type: Copying files for Test dataset, None
# Progress: 11870/11990, operation_type: Copying files for Test dataset, None
# Progress: 11871/11990, operation_type: Copying files for Test dataset, None
# Progress: 11872/11990, operation_type: Copying files for Test dataset, None
# Progress: 11873/11990, operation_type: Copying files for Test dataset, None
# Progress: 11874/11990, operation_type: Copying files for Test dataset, None
# Progress: 11875/11990, operation_type: Copying files for Test dataset, None
# Progress: 11876/11990, operation_type: Copying files for Test dataset, None
# Progress: 11877/11990, operation_type: Copying files for Test dataset, None
# Progress: 11878/11990, operation_type: Copying files for Test dataset, None
# Progress: 11879/11990, operation_type: Copying files for Test dataset, None
# Progress: 11880/11990, operation_type: Copying files for Test dataset, None
# Progress: 11881/11990, operation_type: Copying files for Test dataset, None
# Progress: 11882/11990, operation_type: Copying files for Test dataset, None
# Progress: 11883/11990, operation_type: Copying files for Test dataset, None
# Progress: 11884/11990, operation_type: Copying files for Test dataset, None
# Progress: 11885/11990, operation_type: Copying files for Test dataset, None
# Progress: 11886/11990, operation_type: Copying files for Test dataset, None
# Progress: 11887/11990, operation_type: Copying files for Test dataset, None
# Progress: 11888/11990, operation_type: Copying files for Test dataset, None
# Progress: 11889/11990, operation_type: Copying files for Test dataset, None
# Progress: 11890/11990, operation_type: Copying files for Test dataset, None
# Progress: 11891/11990, operation_type: Copying files for Test dataset, None
# Progress: 11892/11990, operation_type: Copying files for Test dataset, None
# Progress: 11893/11990, operation_type: Copying files for Test dataset, None
# Progress: 11894/11990, operation_type: Copying files for Test dataset, None
# Progress: 11895/11990, operation_type: Copying files for Test dataset, None
# Progress: 11896/11990, operation_type: Copying files for Test dataset, None
# Progress: 11897/11990, operation_type: Copying files for Test dataset, None
# Progress: 11898/11990, operation_type: Copying files for Test dataset, None
# Progress: 11899/11990, operation_type: Copying files for Test dataset, None
# Progress: 11900/11990, operation_type: Copying files for Test dataset, None
# Progress: 11901/11990, operation_type: Copying files for Test dataset, None
# Progress: 11902/11990, operation_type: Copying files for Test dataset, None
# Progress: 11903/11990, operation_type: Copying files for Test dataset, None
# Progress: 11904/11990, operation_type: Copying files for Test dataset, None
# Progress: 11905/11990, operation_type: Copying files for Test dataset, None
# Progress: 11906/11990, operation_type: Copying files for Test dataset, None
# Progress: 11907/11990, operation_type: Copying files for Test dataset, None
# Progress: 11908/11990, operation_type: Copying files for Test dataset, None
# Progress: 11909/11990, operation_type: Copying files for Test dataset, None
# Progress: 11910/11990, operation_type: Copying files for Test dataset, None
# Progress: 11911/11990, operation_type: Copying files for Test dataset, None
# Progress: 11912/11990, operation_type: Copying files for Test dataset, None
# Progress: 11913/11990, operation_type: Copying files for Test dataset, None
# Progress: 11914/11990, operation_type: Copying files for Test dataset, None
# Progress: 11915/11990, operation_type: Copying files for Test dataset, None
# Progress: 11916/11990, operation_type: Copying files for Test dataset, None
# Progress: 11917/11990, operation_type: Copying files for Test dataset, None
# Progress: 11918/11990, operation_type: Copying files for Test dataset, None
# Progress: 11919/11990, operation_type: Copying files for Test dataset, None
# Progress: 11920/11990, operation_type: Copying files for Test dataset, None
# Progress: 11921/11990, operation_type: Copying files for Test dataset, None
# Progress: 11922/11990, operation_type: Copying files for Test dataset, None
# Progress: 11923/11990, operation_type: Copying files for Test dataset, None
# Progress: 11924/11990, operation_type: Copying files for Test dataset, None
# Progress: 11925/11990, operation_type: Copying files for Test dataset, None
# Progress: 11926/11990, operation_type: Copying files for Test dataset, None
# Progress: 11927/11990, operation_type: Copying files for Test dataset, None
# Progress: 11928/11990, operation_type: Copying files for Test dataset, None
# Progress: 11929/11990, operation_type: Copying files for Test dataset, None
# Progress: 11930/11990, operation_type: Copying files for Test dataset, None
# Progress: 11931/11990, operation_type: Copying files for Test dataset, None
# Progress: 11932/11990, operation_type: Copying files for Test dataset, None
# Progress: 11933/11990, operation_type: Copying files for Test dataset, None
# Progress: 11934/11990, operation_type: Copying files for Test dataset, None
# Progress: 11935/11990, operation_type: Copying files for Test dataset, None
# Progress: 11936/11990, operation_type: Copying files for Test dataset, None
# Progress: 11937/11990, operation_type: Copying files for Test dataset, None
# Progress: 11938/11990, operation_type: Copying files for Test dataset, None
# Progress: 11939/11990, operation_type: Copying files for Test dataset, None
# Progress: 11940/11990, operation_type: Copying files for Test dataset, None
# Progress: 11941/11990, operation_type: Copying files for Test dataset, None
# Progress: 11942/11990, operation_type: Copying files for Test dataset, None
# Progress: 11943/11990, operation_type: Copying files for Test dataset, None
# Progress: 11944/11990, operation_type: Copying files for Test dataset, None
# Progress: 11945/11990, operation_type: Copying files for Test dataset, None
# Progress: 11946/11990, operation_type: Copying files for Test dataset, None
# Progress: 11947/11990, operation_type: Copying files for Test dataset, None
# Progress: 11948/11990, operation_type: Copying files for Test dataset, None
# Progress: 11949/11990, operation_type: Copying files for Test dataset, None
# Progress: 11950/11990, operation_type: Copying files for Test dataset, None
# Progress: 11951/11990, operation_type: Copying files for Test dataset, None
# Progress: 11952/11990, operation_type: Copying files for Test dataset, None
# Progress: 11953/11990, operation_type: Copying files for Test dataset, None
# Progress: 11954/11990, operation_type: Copying files for Test dataset, None
# Progress: 11955/11990, operation_type: Copying files for Test dataset, None
# Progress: 11956/11990, operation_type: Copying files for Test dataset, None
# Progress: 11957/11990, operation_type: Copying files for Test dataset, None
# Progress: 11958/11990, operation_type: Copying files for Test dataset, None
# Progress: 11959/11990, operation_type: Copying files for Test dataset, None
# Progress: 11960/11990, operation_type: Copying files for Test dataset, None
# Progress: 11961/11990, operation_type: Copying files for Test dataset, None
# Progress: 11962/11990, operation_type: Copying files for Test dataset, None
# Progress: 11963/11990, operation_type: Copying files for Test dataset, None
# Progress: 11964/11990, operation_type: Copying files for Test dataset, None
# Progress: 11965/11990, operation_type: Copying files for Test dataset, None
# Progress: 11966/11990, operation_type: Copying files for Test dataset, None
# Progress: 11967/11990, operation_type: Copying files for Test dataset, None
# Progress: 11968/11990, operation_type: Copying files for Test dataset, None
# Progress: 11969/11990, operation_type: Copying files for Test dataset, None
# Progress: 11970/11990, operation_type: Copying files for Test dataset, None
# Progress: 11971/11990, operation_type: Copying files for Test dataset, None
# Progress: 11972/11990, operation_type: Copying files for Test dataset, None
# Progress: 11973/11990, operation_type: Copying files for Test dataset, None
# Progress: 11974/11990, operation_type: Copying files for Test dataset, None
# Progress: 11975/11990, operation_type: Copying files for Test dataset, None
# Progress: 11976/11990, operation_type: Copying files for Test dataset, None
# Progress: 11977/11990, operation_type: Copying files for Test dataset, None
# Progress: 11978/11990, operation_type: Copying files for Test dataset, None
# Progress: 11979/11990, operation_type: Copying files for Test dataset, None
# Progress: 11980/11990, operation_type: Copying files for Test dataset, None
# Progress: 11981/11990, operation_type: Copying files for Test dataset, None
# Progress: 11982/11990, operation_type: Copying files for Test dataset, None
# Progress: 11983/11990, operation_type: Copying files for Test dataset, None
# Progress: 11984/11990, operation_type: Copying files for Test dataset, None
# Progress: 11985/11990, operation_type: Copying files for Test dataset, None
# Progress: 11986/11990, operation_type: Copying files for Test dataset, None
# Progress: 11987/11990, operation_type: Copying files for Test dataset, None
# Progress: 11988/11990, operation_type: Copying files for Test dataset, None
# Progress: 11989/11990, operation_type: Copying files for Test dataset, None
# Train class nc_sample1: 5395, Test class nc_sample1: 600
# Train class pc_sample1: 5395, Test class pc_sample1: 600
# ('/nas_mnt/carruthers/sophia/BIS009_20240701_102850/PECCU/datasets/training/train',
#  '/nas_mnt/carruthers/sophia/BIS009_20240701_102850/PECCU/datasets/training/test')

# %%
# Description: train a torch model
from spacr.deep_spacr import train_test_model

settings = {'src':'/nas_mnt/carruthers/sophia/BIS009_20240701_102850/PECCU/datasets/training', # (path) path to source folder (ends with datasets/training)
            'train':True, # (bool) - Train
            'test': False, # (bool) - Test
            'custom_model':False, # (path) - path to a custom model
            'classes':['nc_sample1','pc_sample1'], # (list) - list of classes (folder names in dataset/training/train or test)
            'model_type':'maxvit_t', # (string) - Name of torch model architecture
            'optimizer_type':'adamw', # (string) - type of optimizer
            'schedule':'reduce_lr_on_plateau', # (string) - type of scheduler (reduce_lr_on_plateau or step_lr)
            'loss_type':'focal_loss', # (string) - Loss function (binary_cross_entropy_with_logits or focal_loss)
            'normalize':True, # (bool) - Apply ImageNet normalization to images before training.
            'image_size':224, # (int) - Size of images, height and width.
            'batch_size':64, # (int) - Nr. of images per batch
            'epochs':100, # (int) - Nr. of epochs for training
            'val_split':0.1, # (float) - Fraction of images in validation dataset
            'learning_rate':0.0001, # (float) - Learning rate per epoch
            'weight_decay':0.00001, # (float) - Fraction of random weights decay (regularization)
            'dropout_rate':0.1, # (float) - Fraction of weights to omit per epoch (regularization)
            'init_weights':True, # (bool) - Initiate model with ImageNet weights
            'amsgrad':True, # (bool) - guard against exploding gradients
            'use_checkpoint':True, # (bool) - checkpoint gradient calculations to save VRAM at the expence of computation
            'gradient_accumulation':True, # (bool) - Accumulate gradients to mimic larger batches
            'gradient_accumulation_steps':4, # (int) - Epochs to accumulate gradients
            'intermedeate_save':True, # Save intermediate states of the model
            'pin_memory':True, # (bool) - Whether to pin memory for the data loader
            'n_jobs':30, # (int) - Number of threads to use
            'train_channels':['r','g','b'], # (list of 'r', 'g', and/or 'b') - PNG channels to use for training
            'augment':False, # (bool) - Augment the dataset, vertical, horizontal flip and rotate each image to artificially expand the dataset 8 fold.
            'verbose':True}

train_test_model(settings)
# Out:
#                             Key  \
# 0                           src
# 1                         train
# 2                          test
# 3                  custom_model
# 4                       classes
# 5                    model_type
# 6                optimizer_type
# 7                      schedule
# 8                     loss_type
# 9                     normalize
# 10                   image_size
# 11                   batch_size
# 12                       epochs
# 13                    val_split
# 14                learning_rate
# 15                 weight_decay
# 16                 dropout_rate
# 17                 init_weights
# 18                      amsgrad
# 19               use_checkpoint
# 20        gradient_accumulation
# 21  gradient_accumulation_steps
# 22            intermedeate_save
# 23                   pin_memory
# 24                       n_jobs
# 25               train_channels
# 26                      augment
# 27                      verbose
# 28                          dst
#
#                                                 Value
# 0   /nas_mnt/carruthers/sophia/BIS009_20240701_102...
# 1                                                True
# 2                                               False
# 3                                               False
# 4                            [nc_sample1, pc_sample1]
# 5                                            maxvit_t
# 6                                               adamw
# 7                                reduce_lr_on_plateau
# 8                                          focal_loss
# 9                                                True
# 10                                                224
# 11                                                 64
# 12                                                100
# 13                                                0.1
# 14                                             0.0001
# 15                                            0.00001
# 16                                                0.1
# 17                                               True
# 18                                               True
# 19                                               True
# 20                                               True
# 21                                                  4
# 22                                               True
# 23                                               True
# 24                                                 30
# 25                                          [r, g, b]
# 26                                              False
# 27                                               True
# 28  /nas_mnt/carruthers/sophia/BIS009_20240701_102...
# Training a network on channels: [1, 2, 3]
# Channel 1: Red, Channel 2: Green, Channel 3: Blue
# Loading Train and validation datasets
# Train data:9711, Validation data:1079
# Generating Dataloader with 30 workers
# Train batches:152, Validation batches:17
# Using cuda for Torch
# Loading Model to cuda...ecture: maxvit_t init_weights: True dropout_rate: 0.1 use_checkpoint: True
# Training ...
# Progress: 1/100, operation_type: Training, Train Loss: 0.002, Val Loss: 0.019, Train acc.: 0.619, Val acc.: 0.604, Train NC acc.: 0.819, Val NC acc.: 0.810, Train PC acc.: 0.417, Val PC acc.: 0.415, Train PRAUC: 0.679, Val PRAUC: 0.663
# Progress: 2/100, operation_type: Training, Train Loss: 0.002, Val Loss: 0.018, Train acc.: 0.755, Val acc.: 0.688, Train NC acc.: 0.790, Val NC acc.: 0.714, Train PC acc.: 0.720, Val PC acc.: 0.664, Train PRAUC: 0.835, Val PRAUC: 0.785
# Progress: 3/100, operation_type: Training, Train Loss: 0.001, Val Loss: 0.015, Train acc.: 0.809, Val acc.: 0.733, Train NC acc.: 0.709, Val NC acc.: 0.619, Train PC acc.: 0.911, Val PC acc.: 0.838, Train PRAUC: 0.909, Val PRAUC: 0.830
# Progress: 4/100, operation_type: Training, Train Loss: 0.001, Val Loss: 0.017, Train acc.: 0.864, Val acc.: 0.753, Train NC acc.: 0.929, Val NC acc.: 0.826, Train PC acc.: 0.799, Val PC acc.: 0.687, Train PRAUC: 0.950, Val PRAUC: 0.858

# %%
# Description: generate a tar dataset

from spacr.io import generate_dataset

settings = {'src':'path', # (path) path to source folder (where origional images were stored)
           'file_metadata':'cell_png', # (Optional, string) string in the path of each image (used to filter images)
           'experiment':'test', # (string) - Name of dataset
           'sample':10000} # (Optional, integer or NoneType) limit for number of images to include in the dataset

generate_dataset(settings)

# %%
# Description: apply a model to a tar dataset

from spacr.deep_spacr import apply_model_to_tar

settings = {'dataset':'path.tar', # (path) - path to tar dataset (ends with .tar) 
            'model_path':'path.pth', # (path) - path to model (ends with .pth) 
            'file_type':'cell_png', # (Optional, string) string in the path of each image (used to filter images)
            'image_size':224, # (int) - Size of images, height and width
            'batch_size':64, # (int) - Nr. of images per batch
            'normalize':True, # (bool) - Apply ImageNet normalization to images before training.
            'score_threshold':0.5, # (float) - Score to byass the classes
            'n_jobs':30, # (int) - Number of threads to use
            'verbose':True}

result_df = apply_model_to_tar(settings)

# %%
# Description: Fit a regression model to estimate the effect size of gRNAs on cell scores.
from spacr.ml import perform_regression
import pandas as pd
# %matplotlib inline

settings = {'count_data':'path', # (path) path or list of paths to sequencing count data
            'score_data':'path', # (path) path or list of paths to score data
            'score_column':'column', # () - column with cell scores
            'metadata_files':['path.csv','path.csv'], # (list) pahts to gene metadata 
            'positive_control':'gene', # (string) - gene to highlight in volcano plot
            'negative_control':'gene', # (string) - gene to highlight in volcano plot
            'min_n':3, # () - 
            'fraction_threshold':None, # (Optional, float or NoneType) - Minimum threshold for gene fraction, if None automatically calculated
            'target_unique_count':5, # () - Number of expected unique gRNAs per well
            'tolerance':0.02, # (float) - Tollerance for cells per well limit
            'log_x':False, # () - gRNA Fraction plot X axis log
            'log_y':False, # () - gRNA Fraction plot Y axis log
            'x_lim':None, # () - Volcano X axis limit
            'control_wells':['c1','c2','c3'], # (list) - Metadata to exclude from regression model
            'filter_column':'column', # (str) - Column containing control metadata to remove
            'dependent_variable': 'column', # (string) - Dependent variable for regression
            'threshold_method':'var', # (string) - effect size thresold type (std or var)
            'threshold_multiplier':4, # (integer) - effect size threshold multiplyer 
            'transform':'log', # (string) - Transform dependent variable
            'agg_type':'mean', # (string) - aggregation for dependent variable
            'min_cell_count':None, # (integer) - Minimum number of cells per well
            'regression_type':'ols', # (string) - Type of regression (ols, glm, mixed, ridge, lasso).
            'random_row_column_effects':False, # (bool) - Remove plate , row and column random effects.
            'y_lims':[[0,9], [12, 16]], # (list of lists) limits for broken y axis
            'plate':None, # (string or NoneType) - strinf to replace plate column values with
            'cov_type':None, # (string) - covariance type for ols regression
            'volcano':'gene', # (string) - mode for significant resuls (gene, grna, all)
            'alpha':0.8} # (float) - alpha for hinge and lasso regression

coef_df = perform_regression(settings)
